# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../External_datasets/Zeisel.h5ad')

# %%
obj.raw = obj.copy()
obj.layers["nome"] = obj.X.copy()
obj.layers["log"] = obj.X.copy()
obj.layers["scale"] = obj.X.copy()

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 4000 genes across 3005 cells

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
sf.DNN(obj, group_by="labels0", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                128032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 128,871
# Trainable params: 128,775
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 25/25 [==============================] - 3s 62ms/step - loss: 1.8789 - accuracy: 0.3282 - auc: 0.7002 - precision: 0.6889 - recall: 0.1541 - val_loss: 1.6151 - val_accuracy: 0.3128 - val_auc: 0.7868 - val_precision: 1.0000 - val_recall: 0.2013
#
# Epoch 00001: val_loss improved from inf to 1.61508, saving model to weights/best_model_labels0.h5
# Epoch 2/100
# 25/25 [==============================] - 0s 20ms/step - loss: 1.6419 - accuracy: 0.3927 - auc: 0.8302 - precision: 0.9785 - recall: 0.1252 - val_loss: 1.5227 - val_accuracy: 0.3178 - val_auc: 0.8543 - val_precision: 1.0000 - val_recall: 0.0050
#
# Epoch 00002: val_loss improved from 1.61508 to 1.52268, saving model to weights/best_model_labels0.h5
# Epoch 3/100
# 25/25 [==============================] - 0s 20ms/step - loss: 1.4737 - accuracy: 0.4917 - auc: 0.8874 - precision: 0.9891 - recall: 0.0626 - val_loss: 1.4456 - val_accuracy: 0.4309 - val_auc: 0.9019 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 1.52268 to 1.44562, saving model to weights/best_model_labels0.h5
# Epoch 4/100
# 25/25 [==============================] - 1s 28ms/step - loss: 1.3757 - accuracy: 0.6261 - auc: 0.9263 - precision: 0.9669 - recall: 0.0191 - val_loss: 1.3740 - val_accuracy: 0.5408 - val_auc: 0.9345 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss improved from 1.44562 to 1.37401, saving model to weights/best_model_labels0.h5
# Epoch 5/100
# 25/25 [==============================] - 1s 32ms/step - loss: 1.3243 - accuracy: 0.7405 - auc: 0.9528 - precision: 1.0000 - recall: 0.0088 - val_loss: 1.2979 - val_accuracy: 0.7171 - val_auc: 0.9683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss improved from 1.37401 to 1.29786, saving model to weights/best_model_labels0.h5
# Epoch 6/100
# 25/25 [==============================] - 1s 29ms/step - loss: 1.2023 - accuracy: 0.8160 - auc: 0.9703 - precision: 1.0000 - recall: 0.0127 - val_loss: 1.2427 - val_accuracy: 0.8586 - val_auc: 0.9828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00006: val_loss improved from 1.29786 to 1.24272, saving model to weights/best_model_labels0.h5
# Epoch 7/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.1584 - accuracy: 0.8455 - auc: 0.9772 - precision: 1.0000 - recall: 0.0221 - val_loss: 1.1936 - val_accuracy: 0.8968 - val_auc: 0.9863 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00007: val_loss improved from 1.24272 to 1.19359, saving model to weights/best_model_labels0.h5
# Epoch 8/100
# 25/25 [==============================] - 1s 27ms/step - loss: 1.1074 - accuracy: 0.8472 - auc: 0.9787 - precision: 1.0000 - recall: 0.0483 - val_loss: 1.0898 - val_accuracy: 0.9368 - val_auc: 0.9923 - val_precision: 1.0000 - val_recall: 0.0067
#
# Epoch 00008: val_loss improved from 1.19359 to 1.08981, saving model to weights/best_model_labels0.h5
# Epoch 9/100
# 25/25 [==============================] - 0s 19ms/step - loss: 1.0669 - accuracy: 0.8797 - auc: 0.9807 - precision: 1.0000 - recall: 0.0730 - val_loss: 1.0747 - val_accuracy: 0.9251 - val_auc: 0.9909 - val_precision: 1.0000 - val_recall: 0.0266
#
# Epoch 00009: val_loss improved from 1.08981 to 1.07471, saving model to weights/best_model_labels0.h5
# Epoch 10/100
# 25/25 [==============================] - 0s 18ms/step - loss: 1.0199 - accuracy: 0.8690 - auc: 0.9812 - precision: 0.9912 - recall: 0.1030 - val_loss: 0.9987 - val_accuracy: 0.9301 - val_auc: 0.9927 - val_precision: 1.0000 - val_recall: 0.0899
#
# Epoch 00010: val_loss improved from 1.07471 to 0.99871, saving model to weights/best_model_labels0.h5
# Epoch 11/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.9448 - accuracy: 0.8753 - auc: 0.9860 - precision: 0.9989 - recall: 0.1636 - val_loss: 0.9676 - val_accuracy: 0.9285 - val_auc: 0.9921 - val_precision: 1.0000 - val_recall: 0.1414
#
# Epoch 00011: val_loss improved from 0.99871 to 0.96759, saving model to weights/best_model_labels0.h5
# Epoch 12/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.9132 - accuracy: 0.8890 - auc: 0.9865 - precision: 0.9962 - recall: 0.2005 - val_loss: 0.9576 - val_accuracy: 0.9168 - val_auc: 0.9908 - val_precision: 1.0000 - val_recall: 0.2080
#
# Epoch 00012: val_loss improved from 0.96759 to 0.95760, saving model to weights/best_model_labels0.h5
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.8757 - accuracy: 0.8839 - auc: 0.9846 - precision: 0.9969 - recall: 0.2487 - val_loss: 0.8811 - val_accuracy: 0.9285 - val_auc: 0.9938 - val_precision: 1.0000 - val_recall: 0.2995
#
# Epoch 00013: val_loss improved from 0.95760 to 0.88106, saving model to weights/best_model_labels0.h5
# Epoch 14/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8402 - accuracy: 0.8913 - auc: 0.9889 - precision: 0.9957 - recall: 0.3075 - val_loss: 0.8345 - val_accuracy: 0.9334 - val_auc: 0.9944 - val_precision: 1.0000 - val_recall: 0.3394
#
# Epoch 00014: val_loss improved from 0.88106 to 0.83447, saving model to weights/best_model_labels0.h5
# Epoch 15/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.8136 - accuracy: 0.9049 - auc: 0.9909 - precision: 0.9990 - recall: 0.3540 - val_loss: 0.8118 - val_accuracy: 0.9334 - val_auc: 0.9932 - val_precision: 1.0000 - val_recall: 0.3710
#
# Epoch 00015: val_loss improved from 0.83447 to 0.81178, saving model to weights/best_model_labels0.h5
# Epoch 16/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.7762 - accuracy: 0.9153 - auc: 0.9933 - precision: 1.0000 - recall: 0.3920 - val_loss: 0.7707 - val_accuracy: 0.9351 - val_auc: 0.9939 - val_precision: 1.0000 - val_recall: 0.4476
#
# Epoch 00016: val_loss improved from 0.81178 to 0.77070, saving model to weights/best_model_labels0.h5
# Epoch 17/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.7273 - accuracy: 0.9247 - auc: 0.9936 - precision: 0.9984 - recall: 0.4447 - val_loss: 0.7525 - val_accuracy: 0.9285 - val_auc: 0.9938 - val_precision: 0.9967 - val_recall: 0.5025
#
# Epoch 00017: val_loss improved from 0.77070 to 0.75248, saving model to weights/best_model_labels0.h5
# Epoch 18/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.7118 - accuracy: 0.9187 - auc: 0.9922 - precision: 0.9950 - recall: 0.4651 - val_loss: 0.7009 - val_accuracy: 0.9318 - val_auc: 0.9946 - val_precision: 0.9944 - val_recall: 0.5890
#
# Epoch 00018: val_loss improved from 0.75248 to 0.70091, saving model to weights/best_model_labels0.h5
# Epoch 19/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.6820 - accuracy: 0.9217 - auc: 0.9929 - precision: 0.9977 - recall: 0.5091 - val_loss: 0.6814 - val_accuracy: 0.9351 - val_auc: 0.9950 - val_precision: 0.9974 - val_recall: 0.6439
#
# Epoch 00019: val_loss improved from 0.70091 to 0.68143, saving model to weights/best_model_labels0.h5
# Epoch 20/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.6185 - accuracy: 0.9325 - auc: 0.9944 - precision: 0.9952 - recall: 0.5683 - val_loss: 0.6463 - val_accuracy: 0.9418 - val_auc: 0.9943 - val_precision: 0.9930 - val_recall: 0.7038
#
# Epoch 00020: val_loss improved from 0.68143 to 0.64635, saving model to weights/best_model_labels0.h5
# Epoch 21/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6429 - accuracy: 0.9128 - auc: 0.9927 - precision: 0.9944 - recall: 0.5504 - val_loss: 0.6754 - val_accuracy: 0.9434 - val_auc: 0.9951 - val_precision: 0.9975 - val_recall: 0.6539
#
# Epoch 00021: val_loss did not improve from 0.64635
# Epoch 22/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6235 - accuracy: 0.9124 - auc: 0.9930 - precision: 0.9890 - recall: 0.5805 - val_loss: 0.6330 - val_accuracy: 0.9384 - val_auc: 0.9951 - val_precision: 0.9907 - val_recall: 0.7055
#
# Epoch 00022: val_loss improved from 0.64635 to 0.63299, saving model to weights/best_model_labels0.h5
# Epoch 23/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5755 - accuracy: 0.9344 - auc: 0.9953 - precision: 0.9967 - recall: 0.6339 - val_loss: 0.5819 - val_accuracy: 0.9384 - val_auc: 0.9948 - val_precision: 0.9893 - val_recall: 0.7671
#
# Epoch 00023: val_loss improved from 0.63299 to 0.58188, saving model to weights/best_model_labels0.h5
# Epoch 24/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.5110 - accuracy: 0.9415 - auc: 0.9965 - precision: 0.9969 - recall: 0.6868 - val_loss: 0.5605 - val_accuracy: 0.9418 - val_auc: 0.9949 - val_precision: 0.9875 - val_recall: 0.7870
#
# Epoch 00024: val_loss improved from 0.58188 to 0.56046, saving model to weights/best_model_labels0.h5
# Epoch 25/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5070 - accuracy: 0.9484 - auc: 0.9970 - precision: 0.9908 - recall: 0.7225 - val_loss: 0.5422 - val_accuracy: 0.9451 - val_auc: 0.9952 - val_precision: 0.9837 - val_recall: 0.8020
#
# Epoch 00025: val_loss improved from 0.56046 to 0.54216, saving model to weights/best_model_labels0.h5
# Epoch 26/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4566 - accuracy: 0.9549 - auc: 0.9980 - precision: 0.9981 - recall: 0.7545 - val_loss: 0.5185 - val_accuracy: 0.9384 - val_auc: 0.9950 - val_precision: 0.9843 - val_recall: 0.8319
#
# Epoch 00026: val_loss improved from 0.54216 to 0.51854, saving model to weights/best_model_labels0.h5
# Epoch 27/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4379 - accuracy: 0.9599 - auc: 0.9979 - precision: 0.9973 - recall: 0.7832 - val_loss: 0.5000 - val_accuracy: 0.9401 - val_auc: 0.9951 - val_precision: 0.9881 - val_recall: 0.8270
#
# Epoch 00027: val_loss improved from 0.51854 to 0.49995, saving model to weights/best_model_labels0.h5
# Epoch 28/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4157 - accuracy: 0.9652 - auc: 0.9986 - precision: 0.9978 - recall: 0.8239 - val_loss: 0.4798 - val_accuracy: 0.9468 - val_auc: 0.9946 - val_precision: 0.9845 - val_recall: 0.8436
#
# Epoch 00028: val_loss improved from 0.49995 to 0.47980, saving model to weights/best_model_labels0.h5
# Epoch 29/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4124 - accuracy: 0.9731 - auc: 0.9991 - precision: 0.9985 - recall: 0.8400 - val_loss: 0.4601 - val_accuracy: 0.9468 - val_auc: 0.9952 - val_precision: 0.9828 - val_recall: 0.8552
#
# Epoch 00029: val_loss improved from 0.47980 to 0.46011, saving model to weights/best_model_labels0.h5
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3856 - accuracy: 0.9722 - auc: 0.9993 - precision: 0.9973 - recall: 0.8401 - val_loss: 0.4482 - val_accuracy: 0.9468 - val_auc: 0.9951 - val_precision: 0.9828 - val_recall: 0.8552
#
# Epoch 00030: val_loss improved from 0.46011 to 0.44822, saving model to weights/best_model_labels0.h5
# Epoch 31/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3612 - accuracy: 0.9673 - auc: 0.9991 - precision: 0.9961 - recall: 0.8552 - val_loss: 0.4255 - val_accuracy: 0.9517 - val_auc: 0.9951 - val_precision: 0.9831 - val_recall: 0.8719
#
# Epoch 00031: val_loss improved from 0.44822 to 0.42550, saving model to weights/best_model_labels0.h5
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.9747 - auc: 0.9995 - precision: 0.9993 - recall: 0.8698 - val_loss: 0.5043 - val_accuracy: 0.9235 - val_auc: 0.9937 - val_precision: 0.9735 - val_recall: 0.7953
#
# Epoch 00032: val_loss did not improve from 0.42550
# Epoch 33/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3982 - accuracy: 0.9295 - auc: 0.9954 - precision: 0.9921 - recall: 0.8016 - val_loss: 0.4248 - val_accuracy: 0.9451 - val_auc: 0.9954 - val_precision: 0.9867 - val_recall: 0.8636
#
# Epoch 00033: val_loss improved from 0.42550 to 0.42485, saving model to weights/best_model_labels0.h5
# Epoch 34/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3440 - accuracy: 0.9679 - auc: 0.9991 - precision: 0.9950 - recall: 0.8632 - val_loss: 0.4016 - val_accuracy: 0.9451 - val_auc: 0.9951 - val_precision: 0.9796 - val_recall: 0.8802
#
# Epoch 00034: val_loss improved from 0.42485 to 0.40157, saving model to weights/best_model_labels0.h5
# Epoch 35/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.3153 - accuracy: 0.9695 - auc: 0.9991 - precision: 0.9958 - recall: 0.8691 - val_loss: 0.3729 - val_accuracy: 0.9501 - val_auc: 0.9959 - val_precision: 0.9818 - val_recall: 0.8968
#
# Epoch 00035: val_loss improved from 0.40157 to 0.37290, saving model to weights/best_model_labels0.h5
# Epoch 36/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3120 - accuracy: 0.9732 - auc: 0.9994 - precision: 0.9959 - recall: 0.9025 - val_loss: 0.3754 - val_accuracy: 0.9451 - val_auc: 0.9956 - val_precision: 0.9780 - val_recall: 0.8869
#
# Epoch 00036: val_loss did not improve from 0.37290
# Epoch 37/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2941 - accuracy: 0.9772 - auc: 0.9995 - precision: 0.9962 - recall: 0.8953 - val_loss: 0.3542 - val_accuracy: 0.9501 - val_auc: 0.9957 - val_precision: 0.9801 - val_recall: 0.9018
#
# Epoch 00037: val_loss improved from 0.37290 to 0.35419, saving model to weights/best_model_labels0.h5
# Epoch 38/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2797 - accuracy: 0.9713 - auc: 0.9992 - precision: 0.9971 - recall: 0.9075 - val_loss: 0.3445 - val_accuracy: 0.9501 - val_auc: 0.9958 - val_precision: 0.9767 - val_recall: 0.9068
#
# Epoch 00038: val_loss improved from 0.35419 to 0.34451, saving model to weights/best_model_labels0.h5
# Epoch 39/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.9799 - auc: 0.9996 - precision: 0.9969 - recall: 0.9141 - val_loss: 0.3457 - val_accuracy: 0.9468 - val_auc: 0.9958 - val_precision: 0.9765 - val_recall: 0.9002
#
# Epoch 00039: val_loss did not improve from 0.34451
# Epoch 40/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2572 - accuracy: 0.9831 - auc: 0.9995 - precision: 0.9976 - recall: 0.9284 - val_loss: 0.3442 - val_accuracy: 0.9451 - val_auc: 0.9954 - val_precision: 0.9731 - val_recall: 0.9035
#
# Epoch 00040: val_loss improved from 0.34451 to 0.34418, saving model to weights/best_model_labels0.h5
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.9637 - auc: 0.9990 - precision: 0.9924 - recall: 0.8988 - val_loss: 0.3306 - val_accuracy: 0.9451 - val_auc: 0.9957 - val_precision: 0.9750 - val_recall: 0.9101
#
# Epoch 00041: val_loss improved from 0.34418 to 0.33063, saving model to weights/best_model_labels0.h5
# Epoch 42/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2465 - accuracy: 0.9788 - auc: 0.9991 - precision: 0.9923 - recall: 0.9196 - val_loss: 0.3222 - val_accuracy: 0.9451 - val_auc: 0.9959 - val_precision: 0.9715 - val_recall: 0.9068
# Epoch 00042: val_loss improved from 0.33063 to 0.32218, saving model to weights/best_model_labels0.h5
# Epoch 43/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2334 - accuracy: 0.9784 - auc: 0.9996 - precision: 0.9966 - recall: 0.9418 - val_loss: 0.3512 - val_accuracy: 0.9368 - val_auc: 0.9952 - val_precision: 0.9690 - val_recall: 0.8835
#
# Epoch 00043: val_loss did not improve from 0.32218
# Epoch 44/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.3234 - accuracy: 0.9513 - auc: 0.9979 - precision: 0.9834 - recall: 0.8651 - val_loss: 0.3592 - val_accuracy: 0.9401 - val_auc: 0.9955 - val_precision: 0.9727 - val_recall: 0.8885
#
# Epoch 00044: val_loss did not improve from 0.32218
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2424 - accuracy: 0.9750 - auc: 0.9993 - precision: 0.9942 - recall: 0.9116 - val_loss: 0.3083 - val_accuracy: 0.9517 - val_auc: 0.9961 - val_precision: 0.9696 - val_recall: 0.9035
#
# Epoch 00045: val_loss improved from 0.32218 to 0.30833, saving model to weights/best_model_labels0.h5
# Epoch 46/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2281 - accuracy: 0.9710 - auc: 0.9992 - precision: 0.9902 - recall: 0.9190 - val_loss: 0.2804 - val_accuracy: 0.9567 - val_auc: 0.9966 - val_precision: 0.9721 - val_recall: 0.9268
#
# Epoch 00046: val_loss improved from 0.30833 to 0.28038, saving model to weights/best_model_labels0.h5
# Epoch 47/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2291 - accuracy: 0.9766 - auc: 0.9993 - precision: 0.9914 - recall: 0.9396 - val_loss: 0.2817 - val_accuracy: 0.9517 - val_auc: 0.9963 - val_precision: 0.9736 - val_recall: 0.9201
#
# Epoch 00047: val_loss did not improve from 0.28038
# Epoch 48/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2107 - accuracy: 0.9778 - auc: 0.9995 - precision: 0.9937 - recall: 0.9390 - val_loss: 0.2881 - val_accuracy: 0.9434 - val_auc: 0.9959 - val_precision: 0.9715 - val_recall: 0.9085
#
# Epoch 00048: val_loss did not improve from 0.28038
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1963 - accuracy: 0.9842 - auc: 0.9994 - precision: 0.9956 - recall: 0.9432 - val_loss: 0.2728 - val_accuracy: 0.9434 - val_auc: 0.9957 - val_precision: 0.9667 - val_recall: 0.9185
#
# Epoch 00049: val_loss improved from 0.28038 to 0.27277, saving model to weights/best_model_labels0.h5
# Epoch 50/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1748 - accuracy: 0.9852 - auc: 0.9998 - precision: 0.9975 - recall: 0.9591 - val_loss: 0.2549 - val_accuracy: 0.9517 - val_auc: 0.9961 - val_precision: 0.9771 - val_recall: 0.9235
#
# Epoch 00050: val_loss improved from 0.27277 to 0.25488, saving model to weights/best_model_labels0.h5
# Epoch 51/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1953 - accuracy: 0.9823 - auc: 0.9998 - precision: 0.9944 - recall: 0.9468 - val_loss: 0.2668 - val_accuracy: 0.9484 - val_auc: 0.9961 - val_precision: 0.9686 - val_recall: 0.9235
#
# Epoch 00051: val_loss did not improve from 0.25488
# Epoch 52/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1863 - accuracy: 0.9878 - auc: 0.9998 - precision: 0.9960 - recall: 0.9548 - val_loss: 0.2326 - val_accuracy: 0.9601 - val_auc: 0.9969 - val_precision: 0.9757 - val_recall: 0.9368
#
# Epoch 00052: val_loss improved from 0.25488 to 0.23256, saving model to weights/best_model_labels0.h5
# Epoch 53/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1695 - accuracy: 0.9879 - auc: 0.9999 - precision: 0.9974 - recall: 0.9627 - val_loss: 0.2384 - val_accuracy: 0.9517 - val_auc: 0.9966 - val_precision: 0.9723 - val_recall: 0.9334
#
# Epoch 00053: val_loss did not improve from 0.23256
# Epoch 54/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1624 - accuracy: 0.9845 - auc: 0.9998 - precision: 0.9936 - recall: 0.9621 - val_loss: 0.2483 - val_accuracy: 0.9451 - val_auc: 0.9963 - val_precision: 0.9670 - val_recall: 0.9268
#
# Epoch 00054: val_loss did not improve from 0.23256
# Epoch 55/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1565 - accuracy: 0.9827 - auc: 0.9998 - precision: 0.9954 - recall: 0.9596 - val_loss: 0.2476 - val_accuracy: 0.9451 - val_auc: 0.9963 - val_precision: 0.9635 - val_recall: 0.9218
#
# Epoch 00055: val_loss did not improve from 0.23256
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9913 - auc: 0.9999 - precision: 0.9978 - recall: 0.9675 - val_loss: 0.2346 - val_accuracy: 0.9534 - val_auc: 0.9964 - val_precision: 0.9689 - val_recall: 0.9334
#
# Epoch 00056: val_loss did not improve from 0.23256
# Epoch 57/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1499 - accuracy: 0.9815 - auc: 0.9997 - precision: 0.9949 - recall: 0.9594 - val_loss: 0.2250 - val_accuracy: 0.9617 - val_auc: 0.9964 - val_precision: 0.9689 - val_recall: 0.9334
#
# Epoch 00057: val_loss improved from 0.23256 to 0.22500, saving model to weights/best_model_labels0.h5
# Epoch 58/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1625 - accuracy: 0.9862 - auc: 0.9997 - precision: 0.9967 - recall: 0.9613 - val_loss: 0.2294 - val_accuracy: 0.9517 - val_auc: 0.9964 - val_precision: 0.9672 - val_recall: 0.9318
#
# Epoch 00058: val_loss did not improve from 0.22500
# Epoch 59/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9839 - auc: 0.9997 - precision: 0.9955 - recall: 0.9599 - val_loss: 0.2174 - val_accuracy: 0.9501 - val_auc: 0.9966 - val_precision: 0.9656 - val_recall: 0.9334
#
# Epoch 00059: val_loss improved from 0.22500 to 0.21741, saving model to weights/best_model_labels0.h5
# Epoch 60/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9796 - auc: 0.9998 - precision: 0.9935 - recall: 0.9602 - val_loss: 0.2171 - val_accuracy: 0.9484 - val_auc: 0.9967 - val_precision: 0.9688 - val_recall: 0.9285
#
# Epoch 00060: val_loss improved from 0.21741 to 0.21706, saving model to weights/best_model_labels0.h5
# Epoch 61/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9832 - auc: 0.9997 - precision: 0.9917 - recall: 0.9622 - val_loss: 0.2123 - val_accuracy: 0.9501 - val_auc: 0.9966 - val_precision: 0.9623 - val_recall: 0.9334
#
# Epoch 00061: val_loss improved from 0.21706 to 0.21227, saving model to weights/best_model_labels0.h5
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1622 - accuracy: 0.9803 - auc: 0.9995 - precision: 0.9929 - recall: 0.9548 - val_loss: 0.2233 - val_accuracy: 0.9501 - val_auc: 0.9966 - val_precision: 0.9674 - val_recall: 0.9384
#
# Epoch 00062: val_loss did not improve from 0.21227
# Epoch 63/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9897 - auc: 0.9998 - precision: 0.9962 - recall: 0.9643 - val_loss: 0.2146 - val_accuracy: 0.9501 - val_auc: 0.9965 - val_precision: 0.9641 - val_recall: 0.9384
#
# Epoch 00063: val_loss did not improve from 0.21227
# Epoch 64/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1329 - accuracy: 0.9835 - auc: 0.9994 - precision: 0.9941 - recall: 0.9621 - val_loss: 0.2108 - val_accuracy: 0.9534 - val_auc: 0.9966 - val_precision: 0.9640 - val_recall: 0.9368
#
# Epoch 00064: val_loss improved from 0.21227 to 0.21077, saving model to weights/best_model_labels0.h5
# Epoch 65/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1219 - accuracy: 0.9909 - auc: 0.9999 - precision: 0.9962 - recall: 0.9744 - val_loss: 0.2022 - val_accuracy: 0.9484 - val_auc: 0.9967 - val_precision: 0.9626 - val_recall: 0.9434
#
# Epoch 00065: val_loss improved from 0.21077 to 0.20217, saving model to weights/best_model_labels0.h5
# Epoch 66/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1259 - accuracy: 0.9902 - auc: 0.9998 - precision: 0.9946 - recall: 0.9694 - val_loss: 0.2007 - val_accuracy: 0.9517 - val_auc: 0.9969 - val_precision: 0.9640 - val_recall: 0.9368
#
# Epoch 00066: val_loss improved from 0.20217 to 0.20074, saving model to weights/best_model_labels0.h5
# Epoch 67/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1774 - accuracy: 0.9729 - auc: 0.9994 - precision: 0.9884 - recall: 0.9502 - val_loss: 0.2454 - val_accuracy: 0.9468 - val_auc: 0.9966 - val_precision: 0.9652 - val_recall: 0.9218
#
# Epoch 00067: val_loss did not improve from 0.20074
# Epoch 68/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9793 - auc: 0.9993 - precision: 0.9912 - recall: 0.9643 - val_loss: 0.2020 - val_accuracy: 0.9517 - val_auc: 0.9970 - val_precision: 0.9625 - val_recall: 0.9384
#
# Epoch 00068: val_loss did not improve from 0.20074
# Epoch 69/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1616 - accuracy: 0.9746 - auc: 0.9996 - precision: 0.9926 - recall: 0.9531 - val_loss: 0.2053 - val_accuracy: 0.9551 - val_auc: 0.9969 - val_precision: 0.9643 - val_recall: 0.9434
#
# Epoch 00069: val_loss did not improve from 0.20074
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1666 - accuracy: 0.9739 - auc: 0.9994 - precision: 0.9912 - recall: 0.9441 - val_loss: 0.1986 - val_accuracy: 0.9617 - val_auc: 0.9969 - val_precision: 0.9659 - val_recall: 0.9434
#
# Epoch 00070: val_loss improved from 0.20074 to 0.19865, saving model to weights/best_model_labels0.h5
# Epoch 71/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1376 - accuracy: 0.9828 - auc: 0.9997 - precision: 0.9932 - recall: 0.9617 - val_loss: 0.1832 - val_accuracy: 0.9534 - val_auc: 0.9972 - val_precision: 0.9659 - val_recall: 0.9434
#
# Epoch 00071: val_loss improved from 0.19865 to 0.18323, saving model to weights/best_model_labels0.h5
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1125 - accuracy: 0.9864 - auc: 0.9998 - precision: 0.9946 - recall: 0.9762 - val_loss: 0.1831 - val_accuracy: 0.9534 - val_auc: 0.9971 - val_precision: 0.9593 - val_recall: 0.9401
#
# Epoch 00072: val_loss improved from 0.18323 to 0.18311, saving model to weights/best_model_labels0.h5
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1068 - accuracy: 0.9906 - auc: 0.9999 - precision: 0.9963 - recall: 0.9742 - val_loss: 0.1752 - val_accuracy: 0.9601 - val_auc: 0.9972 - val_precision: 0.9659 - val_recall: 0.9434
#
# Epoch 00073: val_loss improved from 0.18311 to 0.17517, saving model to weights/best_model_labels0.h5
# Epoch 74/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1036 - accuracy: 0.9913 - auc: 0.9999 - precision: 0.9949 - recall: 0.9767 - val_loss: 0.1795 - val_accuracy: 0.9584 - val_auc: 0.9972 - val_precision: 0.9642 - val_recall: 0.9418
#
# Epoch 00074: val_loss did not improve from 0.17517
# Epoch 75/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0998 - accuracy: 0.9878 - auc: 0.9998 - precision: 0.9933 - recall: 0.9784 - val_loss: 0.1762 - val_accuracy: 0.9584 - val_auc: 0.9972 - val_precision: 0.9628 - val_recall: 0.9468
#
# Epoch 00075: val_loss did not improve from 0.17517
# Epoch 76/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0966 - accuracy: 0.9930 - auc: 0.9999 - precision: 0.9942 - recall: 0.9822 - val_loss: 0.1783 - val_accuracy: 0.9601 - val_auc: 0.9971 - val_precision: 0.9644 - val_recall: 0.9468
#
# Epoch 00076: val_loss did not improve from 0.17517
# Epoch 77/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1011 - accuracy: 0.9915 - auc: 0.9999 - precision: 0.9968 - recall: 0.9739 - val_loss: 0.1786 - val_accuracy: 0.9551 - val_auc: 0.9970 - val_precision: 0.9660 - val_recall: 0.9468
#
# Epoch 00077: val_loss did not improve from 0.17517
# Epoch 78/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0963 - accuracy: 0.9852 - auc: 0.9998 - precision: 0.9934 - recall: 0.9737 - val_loss: 0.1777 - val_accuracy: 0.9551 - val_auc: 0.9970 - val_precision: 0.9660 - val_recall: 0.9468
#
# Epoch 00078: val_loss did not improve from 0.17517
# Epoch 00078: early stopping
#               precision    recall  f1-score   support
#
#            1       0.91      0.93      0.92        45
#            2       0.97      0.83      0.90        47
#            3       0.92      1.00      0.96        58
#            4       0.75      0.95      0.84        19
#            5       1.00      0.95      0.97       164
#            6       0.99      0.97      0.98       188
#            7       0.89      0.99      0.93        80
#
#     accuracy                           0.96       601
#    macro avg       0.92      0.95      0.93       601
# weighted avg       0.96      0.96      0.96       601
#
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1752 - accuracy: 0.9601 - auc: 0.9972 - precision: 0.9659 - recall: 0.9434

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="labels0", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="labels0", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9257206208425721: Misclassification: 0.07427937915742788
#               precision    recall  f1-score   support
#
#            1       0.91      0.91      0.91        67
#            2       0.92      0.92      0.92        71
#            3       0.87      0.93      0.90        87
#            4       0.96      0.86      0.91        29
#            5       0.94      0.98      0.96       246
#            6       0.93      0.97      0.95       282
#            7       0.94      0.75      0.83       120
#
#     accuracy                           0.93       902
#    macro avg       0.92      0.90      0.91       902
# weighted avg       0.93      0.93      0.92       902

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="labels0", top=2, figsize=(6,10), restricted=False)

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 4000 genes across 3005 cells

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  31.75722861289978
