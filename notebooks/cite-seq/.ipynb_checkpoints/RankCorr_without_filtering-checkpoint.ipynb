# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
# import warnings
# warnings.filterwarnings("default")

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../External_datasets/CITEseq.h5ad')

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 500 genes across 8617 cells

# %% [markdown]
# #### Data split

# %%
s = time.time()

# %%
from sklearn.model_selection import train_test_split

# %%
data = obj.X.copy()

myDict = {}
for idx, c in enumerate(obj.obs["labels"].cat.categories):
    myDict[c] = idx

labels = []
for l in obj.obs["labels"].tolist():
    labels.append(myDict[l])

labels = np.array(labels)

X = data
y = labels

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# #### RankCorr

# %%
sys.path.append("../../../Functions/RankCorr/")
from picturedRocks import Rocks

# %%
genes = obj.var.index.tolist()

# %%
data = Rocks(X_train, y_train)
markers = data.CSrankMarkers(lamb=3.0, writeOut=False, keepZeros=False, onlyNonZero=False)
data.genes = np.array(genes)

# %%
marker_genes = data.markers_to_genes(markers)

# %%
selectedGenes = [x for x in marker_genes if x != 'nan'][:30]

# %%
selectedGenes_dict = {}
selectedGenes_dict["group"] = selectedGenes

# %%
e = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="labels", genes=selectedGenes, classifier="KNN", balance=True, title="RankCorr-KNN")
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9025522041763341: Misclassification: 0.09744779582366592
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       104
#            2       0.92      0.94      0.93       745
#            3       0.79      0.79      0.79        66
#            4       0.90      1.00      0.95        43
#            5       0.89      0.97      0.93       926
#            6       0.12      0.04      0.05        85
#            7       0.95      0.83      0.89        24
#            8       1.00      0.79      0.88        24
#            9       1.00      0.29      0.44        28
#           10       0.99      0.98      0.99       182
#           11       0.98      0.93      0.95       293
#           12       0.36      0.27      0.31        51
#           13       1.00      1.00      1.00        15
#
#     accuracy                           0.90      2586
#    macro avg       0.84      0.76      0.78      2586
# weighted avg       0.88      0.90      0.89      2586

# %% [markdown]
# #### Heatmap selected genes

# %%
matplotlib.rcdefaults()
matplotlib.rcParams.update({'font.size': 11})
ax = sc.pl.DotPlot(obj,
                   selectedGenes,
                   groupby="labels",
                   standard_scale='var',
                   use_raw=True,
                   figsize=(6,10),
                   linewidths=2).style(cmap=mymap, color_on='square', grid=True, dot_edge_lw=1)
ax.swap_axes(swap_axes=True)
# ax.show()

ax.savefig("Figures/RankCorr_top30.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 500 genes across 8617 cells

# %%
print('Elapsed time (s): ', e-s)
# Out:
# Elapsed time (s):  0.8335134983062744
