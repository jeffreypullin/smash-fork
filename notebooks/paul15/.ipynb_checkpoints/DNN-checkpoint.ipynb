# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sm = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From /home/taneda/.local/lib/python3.8/site-packages/smashpy.py:72: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %% [markdown]
# # Loading annData object

# %%
obj = sc.datasets.paul15()
# Out:
# ... storing 'paul15_clusters' as categorical
# Trying to set attribute `.uns` of view, copying.

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 3451 genes across 2730 cells

# %%
dict_annotation = {}

dict_annotation['1Ery']='Ery'
dict_annotation['2Ery']='Ery'
dict_annotation['3Ery']='Ery'
dict_annotation['4Ery']='Ery'
dict_annotation['5Ery']='Ery'
dict_annotation['6Ery']='Ery'
dict_annotation['7MEP']='MEP'
dict_annotation['8Mk']='Mk'
dict_annotation['9GMP']='GMP'
dict_annotation['10GMP']='GMP'
dict_annotation['11DC']='DC'
dict_annotation['12Baso']='Baso'
dict_annotation['13Baso']='Baso'
dict_annotation['14Mo']='Mo'
dict_annotation['15Mo']='Mo'
dict_annotation['16Neu']='Neu'
dict_annotation['17Neu']='Neu'
dict_annotation['18Eos']='Eos'
dict_annotation['19Lymph']='Lymph'

annotation = []
for celltype in obj.obs["paul15_clusters"].tolist():
    annotation.append(dict_annotation[celltype])

obj.obs['annotation'] = annotation
obj.obs['annotation'] = obj.obs['annotation'].astype("category")

# %% [markdown]
# #### Data preparation

# %%
sm.data_preparation(obj)

# %% [markdown]
# #### Removing general genes

# %%
obj = sm.remove_general_genes(obj)

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sm.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_Mouse_bone_marrow.txt")
obj = sm.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_Mouse_HSC.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sm.remove_features_pct(obj, group_by="annotation", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sm.remove_features_pct_2groups(obj, group_by="annotation", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sm.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.98786717752235

# %% [markdown]
# #### DNN

# %%
sm.DNN(obj, group_by="annotation", model=None, balance=True, verbose=True, save=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                49536
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 50,426
# Trainable params: 50,330
# Non-trainable params: 96
# _________________________________________________________________
# None
# WARNING:tensorflow:From /home/taneda/.local/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 22/22 [==============================] - 1s 18ms/step - loss: 2.3074 - accuracy: 0.0916 - auc: 0.6026 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.1028 - val_accuracy: 0.0128 - val_auc: 0.7378 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 2.10282, saving model to weights/best_model_annotation.h5
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 2.0810 - accuracy: 0.2097 - auc: 0.7139 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0363 - val_accuracy: 0.3590 - val_auc: 0.8106 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 2.10282 to 2.03626, saving model to weights/best_model_annotation.h5
# Epoch 3/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.9729 - accuracy: 0.3136 - auc: 0.7646 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9741 - val_accuracy: 0.4487 - val_auc: 0.8493 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 2.03626 to 1.97407, saving model to weights/best_model_annotation.h5
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8630 - accuracy: 0.3846 - auc: 0.8094 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9501 - val_accuracy: 0.4963 - val_auc: 0.8689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss improved from 1.97407 to 1.95007, saving model to weights/best_model_annotation.h5
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8084 - accuracy: 0.4350 - auc: 0.8266 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9182 - val_accuracy: 0.5549 - val_auc: 0.8900 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss improved from 1.95007 to 1.91823, saving model to weights/best_model_annotation.h5
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.7342 - accuracy: 0.4844 - auc: 0.8580 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9219 - val_accuracy: 0.5989 - val_auc: 0.9028 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 1.91823
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.6546 - accuracy: 0.5243 - auc: 0.8759 - precision: 1.0000 - recall: 4.5788e-04 - val_loss: 1.8525 - val_accuracy: 0.6282 - val_auc: 0.9143 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00007: val_loss improved from 1.91823 to 1.85251, saving model to weights/best_model_annotation.h5
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.6038 - accuracy: 0.5444 - auc: 0.8797 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8497 - val_accuracy: 0.6374 - val_auc: 0.9206 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00008: val_loss improved from 1.85251 to 1.84970, saving model to weights/best_model_annotation.h5
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.5693 - accuracy: 0.5879 - auc: 0.9000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.7680 - val_accuracy: 0.6740 - val_auc: 0.9304 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00009: val_loss improved from 1.84970 to 1.76797, saving model to weights/best_model_annotation.h5
# Epoch 10/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.4977 - accuracy: 0.6131 - auc: 0.9182 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.7416 - val_accuracy: 0.6850 - val_auc: 0.9417 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00010: val_loss improved from 1.76797 to 1.74164, saving model to weights/best_model_annotation.h5
# Epoch 11/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.4614 - accuracy: 0.6328 - auc: 0.9218 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.7204 - val_accuracy: 0.6722 - val_auc: 0.9371 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00011: val_loss improved from 1.74164 to 1.72043, saving model to weights/best_model_annotation.h5
# Epoch 12/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.4216 - accuracy: 0.6328 - auc: 0.9218 - precision: 1.0000 - recall: 9.1575e-04 - val_loss: 1.6772 - val_accuracy: 0.6850 - val_auc: 0.9357 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00012: val_loss improved from 1.72043 to 1.67715, saving model to weights/best_model_annotation.h5
# Epoch 13/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.3646 - accuracy: 0.6488 - auc: 0.9307 - precision: 1.0000 - recall: 0.0027 - val_loss: 1.6440 - val_accuracy: 0.6996 - val_auc: 0.9441 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00013: val_loss improved from 1.67715 to 1.64396, saving model to weights/best_model_annotation.h5
# Epoch 14/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.3146 - accuracy: 0.6749 - auc: 0.9429 - precision: 1.0000 - recall: 0.0092 - val_loss: 1.5721 - val_accuracy: 0.7051 - val_auc: 0.9518 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00014: val_loss improved from 1.64396 to 1.57208, saving model to weights/best_model_annotation.h5
# Epoch 15/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.2727 - accuracy: 0.6992 - auc: 0.9451 - precision: 1.0000 - recall: 0.0160 - val_loss: 1.5549 - val_accuracy: 0.6960 - val_auc: 0.9476 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00015: val_loss improved from 1.57208 to 1.55489, saving model to weights/best_model_annotation.h5
# Epoch 16/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.2214 - accuracy: 0.7115 - auc: 0.9542 - precision: 1.0000 - recall: 0.0192 - val_loss: 1.5438 - val_accuracy: 0.6978 - val_auc: 0.9508 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00016: val_loss improved from 1.55489 to 1.54378, saving model to weights/best_model_annotation.h5
# Epoch 17/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.1828 - accuracy: 0.7317 - auc: 0.9566 - precision: 1.0000 - recall: 0.0293 - val_loss: 1.4917 - val_accuracy: 0.7161 - val_auc: 0.9525 - val_precision: 1.0000 - val_recall: 0.0092
#
# Epoch 00017: val_loss improved from 1.54378 to 1.49168, saving model to weights/best_model_annotation.h5
# Epoch 18/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.1327 - accuracy: 0.7514 - auc: 0.9644 - precision: 1.0000 - recall: 0.0421 - val_loss: 1.5285 - val_accuracy: 0.6832 - val_auc: 0.9446 - val_precision: 1.0000 - val_recall: 0.0201
#
# Epoch 00018: val_loss did not improve from 1.49168
# Epoch 19/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.0901 - accuracy: 0.7592 - auc: 0.9677 - precision: 0.9918 - recall: 0.0554 - val_loss: 1.4563 - val_accuracy: 0.7106 - val_auc: 0.9555 - val_precision: 1.0000 - val_recall: 0.0201
#
# Epoch 00019: val_loss improved from 1.49168 to 1.45631, saving model to weights/best_model_annotation.h5
# Epoch 20/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.0670 - accuracy: 0.7711 - auc: 0.9717 - precision: 1.0000 - recall: 0.0627 - val_loss: 1.4308 - val_accuracy: 0.7289 - val_auc: 0.9572 - val_precision: 1.0000 - val_recall: 0.0256
#
# Epoch 00020: val_loss improved from 1.45631 to 1.43079, saving model to weights/best_model_annotation.h5
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.0322 - accuracy: 0.7926 - auc: 0.9720 - precision: 0.9947 - recall: 0.0856 - val_loss: 1.3672 - val_accuracy: 0.7253 - val_auc: 0.9602 - val_precision: 1.0000 - val_recall: 0.0330
#
# Epoch 00021: val_loss improved from 1.43079 to 1.36723, saving model to weights/best_model_annotation.h5
# Epoch 22/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.9818 - accuracy: 0.8031 - auc: 0.9765 - precision: 1.0000 - recall: 0.1090 - val_loss: 1.3668 - val_accuracy: 0.7253 - val_auc: 0.9572 - val_precision: 0.9048 - val_recall: 0.0348
#
# Epoch 00022: val_loss improved from 1.36723 to 1.36685, saving model to weights/best_model_annotation.h5
# Epoch 23/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.9687 - accuracy: 0.8091 - auc: 0.9761 - precision: 0.9964 - recall: 0.1282 - val_loss: 1.2733 - val_accuracy: 0.7582 - val_auc: 0.9655 - val_precision: 0.8438 - val_recall: 0.0495
#
# Epoch 00023: val_loss improved from 1.36685 to 1.27331, saving model to weights/best_model_annotation.h5
# Epoch 24/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.9245 - accuracy: 0.8306 - auc: 0.9794 - precision: 1.0000 - recall: 0.1561 - val_loss: 1.2476 - val_accuracy: 0.7509 - val_auc: 0.9654 - val_precision: 0.8846 - val_recall: 0.0842
#
# Epoch 00024: val_loss improved from 1.27331 to 1.24760, saving model to weights/best_model_annotation.h5
# Epoch 25/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8729 - accuracy: 0.8329 - auc: 0.9831 - precision: 0.9906 - recall: 0.1932 - val_loss: 1.2779 - val_accuracy: 0.7454 - val_auc: 0.9622 - val_precision: 0.8333 - val_recall: 0.0641
#
# Epoch 00025: val_loss did not improve from 1.24760
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8584 - accuracy: 0.8443 - auc: 0.9847 - precision: 0.9940 - recall: 0.2276 - val_loss: 1.1929 - val_accuracy: 0.7546 - val_auc: 0.9669 - val_precision: 0.9140 - val_recall: 0.1557
#
# Epoch 00026: val_loss improved from 1.24760 to 1.19287, saving model to weights/best_model_annotation.h5
# Epoch 27/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8386 - accuracy: 0.8530 - auc: 0.9873 - precision: 1.0000 - recall: 0.2601 - val_loss: 1.1928 - val_accuracy: 0.7546 - val_auc: 0.9658 - val_precision: 0.9136 - val_recall: 0.1355
#
# Epoch 00027: val_loss improved from 1.19287 to 1.19281, saving model to weights/best_model_annotation.h5
# Epoch 28/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7767 - accuracy: 0.8636 - auc: 0.9881 - precision: 0.9969 - recall: 0.2953 - val_loss: 1.1427 - val_accuracy: 0.7656 - val_auc: 0.9684 - val_precision: 0.9231 - val_recall: 0.1758
#
# Epoch 00028: val_loss improved from 1.19281 to 1.14266, saving model to weights/best_model_annotation.h5
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7559 - accuracy: 0.8732 - auc: 0.9897 - precision: 0.9934 - recall: 0.3425 - val_loss: 1.1627 - val_accuracy: 0.7491 - val_auc: 0.9657 - val_precision: 0.9252 - val_recall: 0.1813
#
# Epoch 00029: val_loss did not improve from 1.14266
# Epoch 30/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7084 - accuracy: 0.8892 - auc: 0.9918 - precision: 0.9964 - recall: 0.3842 - val_loss: 1.1535 - val_accuracy: 0.7381 - val_auc: 0.9652 - val_precision: 0.9035 - val_recall: 0.1886
#
# Epoch 00030: val_loss did not improve from 1.14266
# Epoch 31/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6776 - accuracy: 0.8956 - auc: 0.9930 - precision: 0.9989 - recall: 0.4020 - val_loss: 1.1294 - val_accuracy: 0.7418 - val_auc: 0.9659 - val_precision: 0.8976 - val_recall: 0.2088
#
# Epoch 00031: val_loss improved from 1.14266 to 1.12941, saving model to weights/best_model_annotation.h5
# Epoch 32/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.8883 - auc: 0.9915 - precision: 0.9990 - recall: 0.4483 - val_loss: 1.0932 - val_accuracy: 0.7546 - val_auc: 0.9661 - val_precision: 0.9057 - val_recall: 0.2637
#
# Epoch 00032: val_loss improved from 1.12941 to 1.09318, saving model to weights/best_model_annotation.h5
# Epoch 33/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6422 - accuracy: 0.9153 - auc: 0.9942 - precision: 0.9990 - recall: 0.4748 - val_loss: 1.0596 - val_accuracy: 0.7564 - val_auc: 0.9675 - val_precision: 0.9115 - val_recall: 0.3205
#
# Epoch 00033: val_loss improved from 1.09318 to 1.05964, saving model to weights/best_model_annotation.h5
# Epoch 34/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6059 - accuracy: 0.9125 - auc: 0.9940 - precision: 0.9964 - recall: 0.5105 - val_loss: 1.0270 - val_accuracy: 0.7747 - val_auc: 0.9684 - val_precision: 0.9107 - val_recall: 0.3736
#
# Epoch 00034: val_loss improved from 1.05964 to 1.02701, saving model to weights/best_model_annotation.h5
# Epoch 35/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5949 - accuracy: 0.9135 - auc: 0.9944 - precision: 0.9975 - recall: 0.5545 - val_loss: 1.0283 - val_accuracy: 0.7601 - val_auc: 0.9674 - val_precision: 0.8945 - val_recall: 0.3571
#
# Epoch 00035: val_loss did not improve from 1.02701
# Epoch 36/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5971 - accuracy: 0.9190 - auc: 0.9955 - precision: 0.9969 - recall: 0.5865 - val_loss: 1.0204 - val_accuracy: 0.7637 - val_auc: 0.9672 - val_precision: 0.8796 - val_recall: 0.3480
#
# Epoch 00036: val_loss improved from 1.02701 to 1.02040, saving model to weights/best_model_annotation.h5
# Epoch 37/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5466 - accuracy: 0.9185 - auc: 0.9956 - precision: 0.9947 - recall: 0.5966 - val_loss: 1.0074 - val_accuracy: 0.7564 - val_auc: 0.9661 - val_precision: 0.8828 - val_recall: 0.3864
#
# Epoch 00037: val_loss improved from 1.02040 to 1.00739, saving model to weights/best_model_annotation.h5
# Epoch 38/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5556 - accuracy: 0.9249 - auc: 0.9957 - precision: 0.9943 - recall: 0.6355 - val_loss: 0.9971 - val_accuracy: 0.7619 - val_auc: 0.9665 - val_precision: 0.8725 - val_recall: 0.4011
#
# Epoch 00038: val_loss improved from 1.00739 to 0.99708, saving model to weights/best_model_annotation.h5
# Epoch 39/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5098 - accuracy: 0.9327 - auc: 0.9965 - precision: 0.9945 - recall: 0.6603 - val_loss: 1.0024 - val_accuracy: 0.7344 - val_auc: 0.9638 - val_precision: 0.8645 - val_recall: 0.4322
#
# Epoch 00039: val_loss did not improve from 0.99708
# Epoch 40/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4961 - accuracy: 0.9409 - auc: 0.9974 - precision: 0.9960 - recall: 0.6813 - val_loss: 0.9933 - val_accuracy: 0.7582 - val_auc: 0.9641 - val_precision: 0.8561 - val_recall: 0.4359
#
# Epoch 00040: val_loss improved from 0.99708 to 0.99333, saving model to weights/best_model_annotation.h5
# Epoch 41/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4872 - accuracy: 0.9441 - auc: 0.9973 - precision: 0.9935 - recall: 0.7019 - val_loss: 0.9454 - val_accuracy: 0.7527 - val_auc: 0.9666 - val_precision: 0.8525 - val_recall: 0.4762
# Epoch 00041: val_loss improved from 0.99333 to 0.94541, saving model to weights/best_model_annotation.h5
# Epoch 42/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4555 - accuracy: 0.9382 - auc: 0.9974 - precision: 0.9931 - recall: 0.7248 - val_loss: 0.9264 - val_accuracy: 0.7546 - val_auc: 0.9672 - val_precision: 0.8734 - val_recall: 0.5055
#
# Epoch 00042: val_loss improved from 0.94541 to 0.92642, saving model to weights/best_model_annotation.h5
# Epoch 43/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4657 - accuracy: 0.9455 - auc: 0.9978 - precision: 0.9963 - recall: 0.7413 - val_loss: 0.9163 - val_accuracy: 0.7473 - val_auc: 0.9678 - val_precision: 0.8545 - val_recall: 0.5165
#
# Epoch 00043: val_loss improved from 0.92642 to 0.91635, saving model to weights/best_model_annotation.h5
# Epoch 44/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4273 - accuracy: 0.9533 - auc: 0.9980 - precision: 0.9935 - recall: 0.7720 - val_loss: 0.8739 - val_accuracy: 0.7619 - val_auc: 0.9695 - val_precision: 0.8676 - val_recall: 0.5641
#
# Epoch 00044: val_loss improved from 0.91635 to 0.87391, saving model to weights/best_model_annotation.h5
# Epoch 45/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4214 - accuracy: 0.9597 - auc: 0.9981 - precision: 0.9947 - recall: 0.7665 - val_loss: 0.8769 - val_accuracy: 0.7619 - val_auc: 0.9689 - val_precision: 0.8592 - val_recall: 0.5586
#
# Epoch 00045: val_loss did not improve from 0.87391
# Epoch 46/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4127 - accuracy: 0.9483 - auc: 0.9977 - precision: 0.9942 - recall: 0.7802 - val_loss: 0.8512 - val_accuracy: 0.7546 - val_auc: 0.9696 - val_precision: 0.8715 - val_recall: 0.5714
#
# Epoch 00046: val_loss improved from 0.87391 to 0.85124, saving model to weights/best_model_annotation.h5
# Epoch 47/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3920 - accuracy: 0.9547 - auc: 0.9985 - precision: 0.9965 - recall: 0.7830 - val_loss: 0.8713 - val_accuracy: 0.7564 - val_auc: 0.9671 - val_precision: 0.8411 - val_recall: 0.5623
#
# Epoch 00047: val_loss did not improve from 0.85124
# Epoch 48/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3827 - accuracy: 0.9551 - auc: 0.9984 - precision: 0.9950 - recall: 0.8127 - val_loss: 0.9508 - val_accuracy: 0.7253 - val_auc: 0.9596 - val_precision: 0.8379 - val_recall: 0.5018
#
# Epoch 00048: val_loss did not improve from 0.85124
# Epoch 49/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3660 - accuracy: 0.9519 - auc: 0.9982 - precision: 0.9950 - recall: 0.8201 - val_loss: 0.8886 - val_accuracy: 0.7399 - val_auc: 0.9652 - val_precision: 0.8417 - val_recall: 0.5549
#
# Epoch 00049: val_loss did not improve from 0.85124
# Epoch 50/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3504 - accuracy: 0.9579 - auc: 0.9989 - precision: 0.9978 - recall: 0.8237 - val_loss: 0.8396 - val_accuracy: 0.7509 - val_auc: 0.9683 - val_precision: 0.8411 - val_recall: 0.5916
#
# Epoch 00050: val_loss improved from 0.85124 to 0.83961, saving model to weights/best_model_annotation.h5
# Epoch 51/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3505 - accuracy: 0.9643 - auc: 0.9988 - precision: 0.9946 - recall: 0.8402 - val_loss: 0.8502 - val_accuracy: 0.7509 - val_auc: 0.9674 - val_precision: 0.8472 - val_recall: 0.5989
#
# Epoch 00051: val_loss did not improve from 0.83961
# Epoch 52/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3215 - accuracy: 0.9647 - auc: 0.9989 - precision: 0.9968 - recall: 0.8526 - val_loss: 0.8247 - val_accuracy: 0.7509 - val_auc: 0.9679 - val_precision: 0.8519 - val_recall: 0.6319
#
# Epoch 00052: val_loss improved from 0.83961 to 0.82473, saving model to weights/best_model_annotation.h5
# Epoch 53/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3177 - accuracy: 0.9638 - auc: 0.9989 - precision: 0.9941 - recall: 0.8553 - val_loss: 0.8789 - val_accuracy: 0.7326 - val_auc: 0.9636 - val_precision: 0.8215 - val_recall: 0.5733
#
# Epoch 00053: val_loss did not improve from 0.82473
# Epoch 54/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3096 - accuracy: 0.9693 - auc: 0.9991 - precision: 0.9948 - recall: 0.8727 - val_loss: 0.8314 - val_accuracy: 0.7473 - val_auc: 0.9664 - val_precision: 0.8370 - val_recall: 0.6209
#
# Epoch 00054: val_loss did not improve from 0.82473
# Epoch 55/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2963 - accuracy: 0.9744 - auc: 0.9992 - precision: 0.9969 - recall: 0.8810 - val_loss: 0.9082 - val_accuracy: 0.7399 - val_auc: 0.9591 - val_precision: 0.8010 - val_recall: 0.5751
#
# Epoch 00055: val_loss did not improve from 0.82473
# Epoch 56/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2850 - accuracy: 0.9716 - auc: 0.9992 - precision: 0.9964 - recall: 0.8869 - val_loss: 0.8208 - val_accuracy: 0.7509 - val_auc: 0.9662 - val_precision: 0.8262 - val_recall: 0.6355
#
# Epoch 00056: val_loss improved from 0.82473 to 0.82083, saving model to weights/best_model_annotation.h5
# Epoch 57/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2836 - accuracy: 0.9712 - auc: 0.9993 - precision: 0.9974 - recall: 0.8773 - val_loss: 0.8276 - val_accuracy: 0.7582 - val_auc: 0.9653 - val_precision: 0.8238 - val_recall: 0.6337
#
# Epoch 00057: val_loss did not improve from 0.82083
# Epoch 58/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2773 - accuracy: 0.9712 - auc: 0.9995 - precision: 0.9964 - recall: 0.8906 - val_loss: 0.8181 - val_accuracy: 0.7491 - val_auc: 0.9659 - val_precision: 0.8263 - val_recall: 0.6447
#
# Epoch 00058: val_loss improved from 0.82083 to 0.81808, saving model to weights/best_model_annotation.h5
# Epoch 59/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2697 - accuracy: 0.9707 - auc: 0.9995 - precision: 0.9959 - recall: 0.8993 - val_loss: 0.8159 - val_accuracy: 0.7509 - val_auc: 0.9653 - val_precision: 0.8255 - val_recall: 0.6410
#
# Epoch 00059: val_loss improved from 0.81808 to 0.81593, saving model to weights/best_model_annotation.h5
# Epoch 60/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2521 - accuracy: 0.9766 - auc: 0.9995 - precision: 0.9940 - recall: 0.9061 - val_loss: 0.8557 - val_accuracy: 0.7381 - val_auc: 0.9610 - val_precision: 0.8164 - val_recall: 0.6190
#
# Epoch 00060: val_loss did not improve from 0.81593
# Epoch 61/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2388 - accuracy: 0.9762 - auc: 0.9996 - precision: 0.9980 - recall: 0.9139 - val_loss: 0.8225 - val_accuracy: 0.7381 - val_auc: 0.9639 - val_precision: 0.8119 - val_recall: 0.6484
#
# Epoch 00061: val_loss did not improve from 0.81593
# Epoch 62/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2303 - accuracy: 0.9748 - auc: 0.9996 - precision: 0.9955 - recall: 0.9153 - val_loss: 0.8802 - val_accuracy: 0.7253 - val_auc: 0.9581 - val_precision: 0.7946 - val_recall: 0.5879
#
# Epoch 00062: val_loss did not improve from 0.81593
# Epoch 63/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2427 - accuracy: 0.9771 - auc: 0.9997 - precision: 0.9965 - recall: 0.9084 - val_loss: 0.8425 - val_accuracy: 0.7454 - val_auc: 0.9618 - val_precision: 0.8223 - val_recall: 0.6355
#
# Epoch 00063: val_loss did not improve from 0.81593
# Epoch 64/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2465 - accuracy: 0.9803 - auc: 0.9997 - precision: 0.9955 - recall: 0.9190 - val_loss: 0.8202 - val_accuracy: 0.7418 - val_auc: 0.9635 - val_precision: 0.8213 - val_recall: 0.6484
#
# Epoch 00064: val_loss did not improve from 0.81593
# Epoch 00064: early stopping
#               precision    recall  f1-score   support
#
#         Baso       0.48      0.59      0.53        74
#           DC       1.00      1.00      1.00         6
#          Eos       0.29      1.00      0.44         2
#          Ery       0.98      0.92      0.95       219
#          GMP       0.55      0.53      0.54        43
#        Lymph       1.00      1.00      1.00         6
#          MEP       0.57      0.64      0.60        33
#           Mk       0.67      0.57      0.62        14
#           Mo       0.72      0.62      0.67       112
#          Neu       0.56      0.62      0.59        37
#
#     accuracy                           0.74       546
#    macro avg       0.68      0.75      0.69       546
# weighted avg       0.76      0.74      0.75       546
#
# 18/18 [==============================] - 0s 6ms/step - loss: 0.8159 - accuracy: 0.7509 - auc: 0.9653 - precision: 0.8255 - recall: 0.6410

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sm.run_shap(obj, group_by="annotation", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %% [markdown]
# #### Classifiers

# %%
sm.run_classifiers(obj, group_by="annotation", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=False)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.7362637362637363: Misclassification: 0.2637362637362637
#               precision    recall  f1-score   support
#
#         Baso       0.43      0.50      0.47       111
#           DC       1.00      1.00      1.00         9
#          Eos       0.00      0.00      0.00         3
#          Ery       0.90      0.99      0.94       328
#          GMP       0.75      0.42      0.53        65
#        Lymph       1.00      0.67      0.80         9
#          MEP       0.72      0.52      0.60        50
#           Mk       0.50      0.45      0.47        20
#           Mo       0.64      0.74      0.69       168
#          Neu       0.74      0.36      0.48        56
#
#     accuracy                           0.74       819
#    macro avg       0.67      0.56      0.60       819
# weighted avg       0.74      0.74      0.73       819

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sm.sort_and_plot(obj, selectedGenes, group_by="annotation", top=4, figsize=(6,10))
