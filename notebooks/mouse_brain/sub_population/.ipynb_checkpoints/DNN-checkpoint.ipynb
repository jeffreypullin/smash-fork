# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../../External_datasets/mouse_brain_all_cells_20200625_with_annotations.h5ad')
obj.X = obj.X.toarray()

obj = obj[obj.obs["Cell sub annotation"]!="Unk_1"]
obj = obj[obj.obs["Cell sub annotation"]!="Unk_2"]
obj = obj[obj.obs["Cell sub annotation"]!="Ext_Unk_1"]
obj = obj[obj.obs["Cell sub annotation"]!="Ext_Unk_2"]
obj = obj[obj.obs["Cell sub annotation"]!="Ext_Unk_3"]

# %%
new_sub_annotation = []
for c in obj.obs["Cell sub annotation"].tolist():
    if c in ['Ext_Amy_1', 'Ext_Amy_2']:
        new_sub_annotation.append('Ext_Amy')
        
    elif c in ['Ext_Hpc_CA1', 'Ext_Hpc_CA2', 'Ext_Hpc_CA3']:
        new_sub_annotation.append('Ext_Hpc_CA')
        
    elif c in ['Ext_Hpc_DG1', 'Ext_Hpc_DG2']:
        new_sub_annotation.append('Ext_Hpc_DG')
        
    elif c in ['Ext_L5_1', 'Ext_L5_2', 'Ext_L5_3']:
        new_sub_annotation.append('Ext_L5')
        
    elif c in ['Ext_Thal_1', 'Ext_Thal_2']:
        new_sub_annotation.append('Ext_Thal')
        
    elif c in ['Inh_1', 'Inh_2', 'Inh_3', 'Inh_4', 'Inh_5', 'Inh_6']:
        new_sub_annotation.append('Inh')
        
    elif c in ['Inh_Meis2_1', 'Inh_Meis2_2', 'Inh_Meis2_3', 'Inh_Meis2_4']:
        new_sub_annotation.append('Inh_Meis2')
        
    elif c in ['Astro_AMY', 'Astro_AMY_CTX', 'Astro_CTX']:
        new_sub_annotation.append('Astro_AMY_CTX')
        
    elif c in ['Astro_THAL_hab', 'Astro_THAL_lat', 'Astro_THAL_med']:
        new_sub_annotation.append('Astro_THAL')
        
    elif c in ['LowQ_1', 'LowQ_2']:
        new_sub_annotation.append('LowQ')
        
    elif c in ['Nb_1', 'Nb_2']:
        new_sub_annotation.append('Nb')
    
    elif c in ['OPC_1', 'OPC_2']:
        new_sub_annotation.append('OPC')
    
    elif c in ['Oligo_1', 'Oligo_2']:
        new_sub_annotation.append('Oligo')

    else:
        new_sub_annotation.append(c)
obj.obs["Cell sub annotation"] = new_sub_annotation
obj.obs["Cell sub annotation"] = obj.obs["Cell sub annotation"].astype("category")
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 31053 genes across 38872 cells

# %% [markdown]
# #### Data preparation

# %%
sf.data_preparation(obj)

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj, species='mouse')

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_Mouse_cortex.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="Cell sub annotation", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="Cell sub annotation", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.9384991843393149

# %%
obj.var.set_index(obj.var["SYMBOL"], inplace=True, drop=False)
obj.var.index.name = None

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
sf.DNN(obj, group_by="Cell sub annotation", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                184128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 31)                527
# =================================================================
# Total params: 185,375
# Trainable params: 185,279
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 311/311 [==============================] - 4s 10ms/step - loss: 3.1130 - accuracy: 0.1499 - auc: 0.7394 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6919 - val_accuracy: 0.6360 - val_auc: 0.9463 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 2.69192, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 2/100
# 311/311 [==============================] - 2s 8ms/step - loss: 2.4817 - accuracy: 0.4870 - auc: 0.9024 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0941 - val_accuracy: 0.7513 - val_auc: 0.9792 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 2.69192 to 2.09407, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 3/100
# 311/311 [==============================] - 2s 8ms/step - loss: 1.8993 - accuracy: 0.5946 - auc: 0.9500 - precision: 0.8878 - recall: 0.0039 - val_loss: 1.6414 - val_accuracy: 0.8365 - val_auc: 0.9892 - val_precision: 0.9971 - val_recall: 0.0449
#
# Epoch 00003: val_loss improved from 2.09407 to 1.64145, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 4/100
# 311/311 [==============================] - 2s 8ms/step - loss: 1.5135 - accuracy: 0.6709 - auc: 0.9724 - precision: 0.9968 - recall: 0.0689 - val_loss: 1.1406 - val_accuracy: 0.9410 - val_auc: 0.9970 - val_precision: 0.9979 - val_recall: 0.3052
#
# Epoch 00004: val_loss improved from 1.64145 to 1.14064, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 5/100
# 311/311 [==============================] - 2s 7ms/step - loss: 1.1209 - accuracy: 0.7887 - auc: 0.9886 - precision: 0.9951 - recall: 0.2267 - val_loss: 0.8799 - val_accuracy: 0.9459 - val_auc: 0.9979 - val_precision: 0.9936 - val_recall: 0.4799
#
# Epoch 00005: val_loss improved from 1.14064 to 0.87990, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 6/100
# 311/311 [==============================] - 2s 8ms/step - loss: 0.8795 - accuracy: 0.8530 - auc: 0.9944 - precision: 0.9938 - recall: 0.3755 - val_loss: 0.6000 - val_accuracy: 0.9473 - val_auc: 0.9986 - val_precision: 0.9871 - val_recall: 0.6669
#
# Epoch 00006: val_loss improved from 0.87990 to 0.60000, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 7/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.7288 - accuracy: 0.8804 - auc: 0.9967 - precision: 0.9925 - recall: 0.5316 - val_loss: 0.4711 - val_accuracy: 0.9506 - val_auc: 0.9987 - val_precision: 0.9816 - val_recall: 0.8050
#
# Epoch 00007: val_loss improved from 0.60000 to 0.47111, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 8/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.5861 - accuracy: 0.9027 - auc: 0.9978 - precision: 0.9900 - recall: 0.6545 - val_loss: 0.3812 - val_accuracy: 0.9518 - val_auc: 0.9988 - val_precision: 0.9812 - val_recall: 0.8586
#
# Epoch 00008: val_loss improved from 0.47111 to 0.38117, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 9/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.5047 - accuracy: 0.9164 - auc: 0.9985 - precision: 0.9894 - recall: 0.7286 - val_loss: 0.2811 - val_accuracy: 0.9567 - val_auc: 0.9990 - val_precision: 0.9807 - val_recall: 0.9077
#
# Epoch 00009: val_loss improved from 0.38117 to 0.28107, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 10/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.4369 - accuracy: 0.9266 - auc: 0.9987 - precision: 0.9872 - recall: 0.7778 - val_loss: 0.2688 - val_accuracy: 0.9538 - val_auc: 0.9989 - val_precision: 0.9776 - val_recall: 0.9096
#
# Epoch 00010: val_loss improved from 0.28107 to 0.26878, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 11/100
# 311/311 [==============================] - 2s 8ms/step - loss: 0.3715 - accuracy: 0.9378 - auc: 0.9990 - precision: 0.9881 - recall: 0.8232 - val_loss: 0.2357 - val_accuracy: 0.9529 - val_auc: 0.9986 - val_precision: 0.9710 - val_recall: 0.9255
#
# Epoch 00011: val_loss improved from 0.26878 to 0.23568, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 12/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.3281 - accuracy: 0.9412 - auc: 0.9992 - precision: 0.9857 - recall: 0.8458 - val_loss: 0.1986 - val_accuracy: 0.9618 - val_auc: 0.9989 - val_precision: 0.9736 - val_recall: 0.9434
#
# Epoch 00012: val_loss improved from 0.23568 to 0.19857, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 13/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.3014 - accuracy: 0.9459 - auc: 0.9993 - precision: 0.9833 - recall: 0.8695 - val_loss: 0.1642 - val_accuracy: 0.9641 - val_auc: 0.9989 - val_precision: 0.9723 - val_recall: 0.9527
#
# Epoch 00013: val_loss improved from 0.19857 to 0.16418, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 14/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.2626 - accuracy: 0.9547 - auc: 0.9994 - precision: 0.9858 - recall: 0.8965 - val_loss: 0.1772 - val_accuracy: 0.9617 - val_auc: 0.9987 - val_precision: 0.9716 - val_recall: 0.9513
#
# Epoch 00014: val_loss did not improve from 0.16418
# Epoch 15/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.2368 - accuracy: 0.9559 - auc: 0.9995 - precision: 0.9846 - recall: 0.9013 - val_loss: 0.1714 - val_accuracy: 0.9609 - val_auc: 0.9986 - val_precision: 0.9688 - val_recall: 0.9495
#
# Epoch 00015: val_loss did not improve from 0.16418
# Epoch 16/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.2176 - accuracy: 0.9559 - auc: 0.9995 - precision: 0.9823 - recall: 0.9089 - val_loss: 0.1529 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_precision: 0.9695 - val_recall: 0.9527
#
# Epoch 00016: val_loss improved from 0.16418 to 0.15288, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 17/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.2055 - accuracy: 0.9586 - auc: 0.9996 - precision: 0.9822 - recall: 0.9185 - val_loss: 0.1461 - val_accuracy: 0.9619 - val_auc: 0.9985 - val_precision: 0.9696 - val_recall: 0.9564
#
# Epoch 00017: val_loss improved from 0.15288 to 0.14605, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 18/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1946 - accuracy: 0.9588 - auc: 0.9996 - precision: 0.9827 - recall: 0.9247 - val_loss: 0.1417 - val_accuracy: 0.9610 - val_auc: 0.9984 - val_precision: 0.9673 - val_recall: 0.9543
#
# Epoch 00018: val_loss improved from 0.14605 to 0.14171, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 19/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1788 - accuracy: 0.9645 - auc: 0.9997 - precision: 0.9841 - recall: 0.9330 - val_loss: 0.1355 - val_accuracy: 0.9636 - val_auc: 0.9985 - val_precision: 0.9700 - val_recall: 0.9596
#
# Epoch 00019: val_loss improved from 0.14171 to 0.13549, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 20/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1670 - accuracy: 0.9607 - auc: 0.9997 - precision: 0.9821 - recall: 0.9311 - val_loss: 0.1554 - val_accuracy: 0.9567 - val_auc: 0.9982 - val_precision: 0.9652 - val_recall: 0.9511
#
# Epoch 00020: val_loss did not improve from 0.13549
# Epoch 21/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1672 - accuracy: 0.9631 - auc: 0.9997 - precision: 0.9832 - recall: 0.9350 - val_loss: 0.1380 - val_accuracy: 0.9641 - val_auc: 0.9978 - val_precision: 0.9691 - val_recall: 0.9603
#
# Epoch 00021: val_loss did not improve from 0.13549
# Epoch 22/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1505 - accuracy: 0.9658 - auc: 0.9997 - precision: 0.9828 - recall: 0.9432 - val_loss: 0.1422 - val_accuracy: 0.9610 - val_auc: 0.9976 - val_precision: 0.9662 - val_recall: 0.9560
#
# Epoch 00022: val_loss did not improve from 0.13549
# Epoch 23/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1456 - accuracy: 0.9678 - auc: 0.9997 - precision: 0.9838 - recall: 0.9477 - val_loss: 0.1448 - val_accuracy: 0.9628 - val_auc: 0.9971 - val_precision: 0.9675 - val_recall: 0.9586
#
# Epoch 00023: val_loss did not improve from 0.13549
# Epoch 24/100
# 311/311 [==============================] - 2s 7ms/step - loss: 0.1512 - accuracy: 0.9665 - auc: 0.9998 - precision: 0.9816 - recall: 0.9436 - val_loss: 0.1487 - val_accuracy: 0.9612 - val_auc: 0.9971 - val_precision: 0.9655 - val_recall: 0.9563
#
# Epoch 00024: val_loss did not improve from 0.13549
# Epoch 00024: early stopping
#                precision    recall  f1-score   support
#
# Astro_AMY_CTX       0.87      0.88      0.88       244
#     Astro_HPC       0.55      0.60      0.57        52
#    Astro_HYPO       0.66      0.71      0.68        90
#     Astro_STR       0.45      0.31      0.37        16
#    Astro_THAL       0.83      0.78      0.81       156
#      Astro_WM       0.78      0.82      0.80        44
#          Endo       1.00      1.00      1.00         4
#       Ext_Amy       0.95      0.92      0.93       263
#   Ext_ClauPyr       0.98      1.00      0.99        54
#    Ext_Hpc_CA       0.95      0.99      0.97       190
#    Ext_Hpc_DG       0.99      0.98      0.98       294
#       Ext_L23       0.97      0.95      0.96       249
#       Ext_L25       0.88      0.97      0.93       184
#        Ext_L5       0.95      0.78      0.86       237
#       Ext_L56       1.00      0.99      0.99       284
#        Ext_L6       0.83      0.96      0.89       114
#       Ext_L6B       0.95      1.00      0.97        71
#       Ext_Med       0.63      0.86      0.73        14
#       Ext_Pir       0.89      0.91      0.90       191
#      Ext_Thal       1.00      1.00      1.00       374
#           Inh       0.98      0.99      0.99       841
#     Inh_Lamp5       0.97      0.95      0.96        66
#     Inh_Meis2       0.99      0.97      0.98       390
#     Inh_Pvalb       0.93      0.99      0.96       161
#       Inh_Sst       0.97      0.94      0.95       128
#       Inh_Vip       0.98      0.99      0.99       109
#          LowQ       0.96      0.99      0.97        75
#         Micro       0.99      1.00      1.00       244
#            Nb       0.95      0.98      0.97        86
#           OPC       0.99      1.00      0.99       263
#         Oligo       1.00      1.00      1.00      2287
#
#      accuracy                           0.96      7775
#     macro avg       0.90      0.91      0.90      7775
#  weighted avg       0.96      0.96      0.96      7775
#
# 243/243 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9636 - auc: 0.9985 - precision: 0.9700 - recall: 0.9596

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="Cell sub annotation", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="Cell sub annotation", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9614131366832447: Misclassification: 0.038586863316755315
#                precision    recall  f1-score   support
#
# Astro_AMY_CTX       0.77      0.96      0.85       366
#     Astro_HPC       0.53      0.26      0.34        78
#    Astro_HYPO       0.58      0.69      0.63       135
#     Astro_STR       0.56      0.21      0.30        24
#    Astro_THAL       0.81      0.68      0.74       234
#      Astro_WM       0.97      0.59      0.74        66
#          Endo       0.78      1.00      0.88         7
#       Ext_Amy       0.91      0.95      0.93       395
#   Ext_ClauPyr       0.99      1.00      0.99        82
#    Ext_Hpc_CA       0.98      0.99      0.98       285
#    Ext_Hpc_DG       0.98      0.98      0.98       441
#       Ext_L23       0.91      0.98      0.94       373
#       Ext_L25       0.97      0.84      0.90       277
#        Ext_L5       0.91      0.92      0.92       356
#       Ext_L56       0.99      0.99      0.99       427
#        Ext_L6       0.96      0.94      0.95       170
#       Ext_L6B       0.98      0.97      0.98       107
#       Ext_Med       0.90      0.90      0.90        21
#       Ext_Pir       0.92      0.88      0.90       286
#      Ext_Thal       0.99      1.00      0.99       560
#           Inh       0.99      0.99      0.99      1261
#     Inh_Lamp5       0.94      0.98      0.96        99
#     Inh_Meis2       0.99      0.99      0.99       584
#     Inh_Pvalb       0.96      0.99      0.98       241
#       Inh_Sst       0.98      0.94      0.96       192
#       Inh_Vip       0.98      0.97      0.97       164
#          LowQ       1.00      0.97      0.99       113
#         Micro       1.00      1.00      1.00       365
#            Nb       0.97      0.95      0.96       128
#           OPC       1.00      1.00      1.00       395
#         Oligo       1.00      1.00      1.00      3430
#
#      accuracy                           0.96     11662
#     macro avg       0.91      0.89      0.89     11662
#  weighted avg       0.96      0.96      0.96     11662

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="Cell sub annotation", top=3, figsize=(13,25))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 5753 genes across 38872 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  27371.969893932343

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  26218.69275522232
