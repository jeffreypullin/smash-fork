# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../External_datasets/mouse_brain_all_cells_20200625_with_annotations.h5ad')
obj.X = obj.X.toarray()
obj = obj[obj.obs["Cell broad annotation"]!='Unk']

# %%
obj.X = obj.X.toarray()

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 31053 genes across 39583 cells

# %% [markdown]
# #### Data preparation

# %%
sf.data_preparation(obj)

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj, species='mouse')

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../data/house_keeping_genes_Mouse_cortex.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="Cell broad annotation", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="Cell broad annotation", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.900475984422328

# %%
obj.var.set_index(obj.var["SYMBOL"], inplace=True, drop=False)
obj.var.index.name = None

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
sf.DNN(obj, group_by="Cell broad annotation", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                133216
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 153
# =================================================================
# Total params: 134,089
# Trainable params: 133,993
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 317/317 [==============================] - 4s 7ms/step - loss: 1.8814 - accuracy: 0.2362 - auc: 0.6881 - precision: 0.5566 - recall: 0.0013 - val_loss: 1.3674 - val_accuracy: 0.8866 - val_auc: 0.9902 - val_precision: 1.0000 - val_recall: 0.0287
#
# Epoch 00001: val_loss improved from inf to 1.36741, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 2/100
# 317/317 [==============================] - 2s 5ms/step - loss: 1.0918 - accuracy: 0.7791 - auc: 0.9641 - precision: 0.9986 - recall: 0.0601 - val_loss: 1.0126 - val_accuracy: 0.9083 - val_auc: 0.9896 - val_precision: 0.9983 - val_recall: 0.1490
#
# Epoch 00002: val_loss improved from 1.36741 to 1.01257, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 3/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.7379 - accuracy: 0.8811 - auc: 0.9884 - precision: 0.9953 - recall: 0.2602 - val_loss: 0.5530 - val_accuracy: 0.9924 - val_auc: 0.9997 - val_precision: 0.9993 - val_recall: 0.8602
#
# Epoch 00003: val_loss improved from 1.01257 to 0.55303, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 4/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.4910 - accuracy: 0.9446 - auc: 0.9968 - precision: 0.9952 - recall: 0.6447 - val_loss: 0.3234 - val_accuracy: 0.9937 - val_auc: 0.9998 - val_precision: 0.9977 - val_recall: 0.9787
#
# Epoch 00004: val_loss improved from 0.55303 to 0.32343, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 5/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.3358 - accuracy: 0.9632 - auc: 0.9987 - precision: 0.9942 - recall: 0.8287 - val_loss: 0.2854 - val_accuracy: 0.9899 - val_auc: 0.9997 - val_precision: 0.9959 - val_recall: 0.9708
#
# Epoch 00005: val_loss improved from 0.32343 to 0.28537, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 6/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2474 - accuracy: 0.9721 - auc: 0.9993 - precision: 0.9930 - recall: 0.9034 - val_loss: 0.1229 - val_accuracy: 0.9953 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9927
#
# Epoch 00006: val_loss improved from 0.28537 to 0.12286, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 7/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.1866 - accuracy: 0.9795 - auc: 0.9996 - precision: 0.9931 - recall: 0.9400 - val_loss: 0.0833 - val_accuracy: 0.9955 - val_auc: 0.9999 - val_precision: 0.9963 - val_recall: 0.9947
#
# Epoch 00007: val_loss improved from 0.12286 to 0.08335, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 8/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.1497 - accuracy: 0.9830 - auc: 0.9997 - precision: 0.9933 - recall: 0.9571 - val_loss: 0.0593 - val_accuracy: 0.9953 - val_auc: 0.9999 - val_precision: 0.9966 - val_recall: 0.9944
#
# Epoch 00008: val_loss improved from 0.08335 to 0.05927, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 9/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.1168 - accuracy: 0.9860 - auc: 0.9998 - precision: 0.9933 - recall: 0.9694 - val_loss: 0.0459 - val_accuracy: 0.9957 - val_auc: 1.0000 - val_precision: 0.9966 - val_recall: 0.9953
#
# Epoch 00009: val_loss improved from 0.05927 to 0.04588, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 10/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0960 - accuracy: 0.9898 - auc: 0.9999 - precision: 0.9947 - recall: 0.9781 - val_loss: 0.0361 - val_accuracy: 0.9962 - val_auc: 1.0000 - val_precision: 0.9968 - val_recall: 0.9955
#
# Epoch 00010: val_loss improved from 0.04588 to 0.03608, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 11/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0858 - accuracy: 0.9907 - auc: 0.9999 - precision: 0.9950 - recall: 0.9825 - val_loss: 0.0251 - val_accuracy: 0.9968 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9961
#
# Epoch 00011: val_loss improved from 0.03608 to 0.02511, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 12/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0782 - accuracy: 0.9918 - auc: 0.9999 - precision: 0.9954 - recall: 0.9863 - val_loss: 0.0313 - val_accuracy: 0.9963 - val_auc: 0.9999 - val_precision: 0.9971 - val_recall: 0.9955
#
# Epoch 00012: val_loss did not improve from 0.02511
# Epoch 13/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0667 - accuracy: 0.9923 - auc: 0.9999 - precision: 0.9955 - recall: 0.9860 - val_loss: 0.0200 - val_accuracy: 0.9965 - val_auc: 0.9999 - val_precision: 0.9970 - val_recall: 0.9960
#
# Epoch 00013: val_loss improved from 0.02511 to 0.01998, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 14/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0457 - accuracy: 0.9935 - auc: 1.0000 - precision: 0.9962 - recall: 0.9891 - val_loss: 0.0180 - val_accuracy: 0.9955 - val_auc: 0.9999 - val_precision: 0.9956 - val_recall: 0.9953
#
# Epoch 00014: val_loss improved from 0.01998 to 0.01796, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 15/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0418 - accuracy: 0.9947 - auc: 1.0000 - precision: 0.9961 - recall: 0.9915 - val_loss: 0.0143 - val_accuracy: 0.9968 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9967
#
# Epoch 00015: val_loss improved from 0.01796 to 0.01430, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 16/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0373 - accuracy: 0.9953 - auc: 1.0000 - precision: 0.9966 - recall: 0.9919 - val_loss: 0.0125 - val_accuracy: 0.9976 - val_auc: 0.9999 - val_precision: 0.9976 - val_recall: 0.9975
#
# Epoch 00016: val_loss improved from 0.01430 to 0.01246, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 17/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0323 - accuracy: 0.9966 - auc: 1.0000 - precision: 0.9976 - recall: 0.9942 - val_loss: 0.0120 - val_accuracy: 0.9973 - val_auc: 0.9999 - val_precision: 0.9975 - val_recall: 0.9972
#
# Epoch 00017: val_loss improved from 0.01246 to 0.01205, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 18/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0292 - accuracy: 0.9954 - auc: 1.0000 - precision: 0.9965 - recall: 0.9937 - val_loss: 0.0186 - val_accuracy: 0.9970 - val_auc: 0.9998 - val_precision: 0.9973 - val_recall: 0.9963
#
# Epoch 00018: val_loss did not improve from 0.01205
# Epoch 19/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0266 - accuracy: 0.9960 - auc: 1.0000 - precision: 0.9973 - recall: 0.9941 - val_loss: 0.0215 - val_accuracy: 0.9951 - val_auc: 0.9999 - val_precision: 0.9954 - val_recall: 0.9948
#
# Epoch 00019: val_loss did not improve from 0.01205
# Epoch 20/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0344 - accuracy: 0.9968 - auc: 1.0000 - precision: 0.9976 - recall: 0.9949 - val_loss: 0.0126 - val_accuracy: 0.9965 - val_auc: 0.9999 - val_precision: 0.9966 - val_recall: 0.9962
#
# Epoch 00020: val_loss did not improve from 0.01205
# Epoch 21/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0236 - accuracy: 0.9963 - auc: 1.0000 - precision: 0.9970 - recall: 0.9951 - val_loss: 0.0109 - val_accuracy: 0.9970 - val_auc: 0.9999 - val_precision: 0.9971 - val_recall: 0.9970
#
# Epoch 00021: val_loss improved from 0.01205 to 0.01085, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 22/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0233 - accuracy: 0.9969 - auc: 1.0000 - precision: 0.9979 - recall: 0.9959 - val_loss: 0.0120 - val_accuracy: 0.9968 - val_auc: 0.9998 - val_precision: 0.9971 - val_recall: 0.9967
#
# Epoch 00022: val_loss did not improve from 0.01085
# Epoch 23/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9970 - auc: 1.0000 - precision: 0.9977 - recall: 0.9960 - val_loss: 0.0095 - val_accuracy: 0.9975 - val_auc: 0.9998 - val_precision: 0.9975 - val_recall: 0.9975
#
# Epoch 00023: val_loss improved from 0.01085 to 0.00945, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 24/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0189 - accuracy: 0.9974 - auc: 1.0000 - precision: 0.9979 - recall: 0.9965 - val_loss: 0.0094 - val_accuracy: 0.9970 - val_auc: 0.9999 - val_precision: 0.9971 - val_recall: 0.9970
#
# Epoch 00024: val_loss improved from 0.00945 to 0.00940, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 25/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0177 - accuracy: 0.9970 - auc: 1.0000 - precision: 0.9976 - recall: 0.9962 - val_loss: 0.0092 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9973 - val_recall: 0.9971
#
# Epoch 00025: val_loss improved from 0.00940 to 0.00924, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 26/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9971 - auc: 1.0000 - precision: 0.9975 - recall: 0.9964 - val_loss: 0.0111 - val_accuracy: 0.9967 - val_auc: 0.9999 - val_precision: 0.9968 - val_recall: 0.9967
#
# Epoch 00026: val_loss did not improve from 0.00924
# Epoch 27/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0141 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9981 - recall: 0.9970 - val_loss: 0.0091 - val_accuracy: 0.9970 - val_auc: 0.9999 - val_precision: 0.9971 - val_recall: 0.9970
#
# Epoch 00027: val_loss improved from 0.00924 to 0.00908, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 28/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0154 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9980 - recall: 0.9971 - val_loss: 0.0093 - val_accuracy: 0.9975 - val_auc: 0.9998 - val_precision: 0.9975 - val_recall: 0.9973
#
# Epoch 00028: val_loss did not improve from 0.00908
# Epoch 29/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9973 - auc: 1.0000 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0081 - val_accuracy: 0.9976 - val_auc: 0.9999 - val_precision: 0.9976 - val_recall: 0.9975
#
# Epoch 00029: val_loss improved from 0.00908 to 0.00814, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 30/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0115 - accuracy: 0.9979 - auc: 1.0000 - precision: 0.9982 - recall: 0.9975 - val_loss: 0.0081 - val_accuracy: 0.9980 - val_auc: 0.9997 - val_precision: 0.9980 - val_recall: 0.9976
#
# Epoch 00030: val_loss improved from 0.00814 to 0.00806, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 31/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0124 - accuracy: 0.9976 - auc: 1.0000 - precision: 0.9979 - recall: 0.9973 - val_loss: 0.0076 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9975 - val_recall: 0.9972
#
# Epoch 00031: val_loss improved from 0.00806 to 0.00764, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 32/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9979 - auc: 1.0000 - precision: 0.9984 - recall: 0.9975 - val_loss: 0.0076 - val_accuracy: 0.9977 - val_auc: 0.9999 - val_precision: 0.9977 - val_recall: 0.9977
#
# Epoch 00032: val_loss improved from 0.00764 to 0.00761, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 33/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0131 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9981 - recall: 0.9972 - val_loss: 0.0076 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9973 - val_recall: 0.9972
#
# Epoch 00033: val_loss improved from 0.00761 to 0.00755, saving model to weights/best_model_Cell broad annotation.h5
# Epoch 34/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0088 - accuracy: 0.9988 - auc: 1.0000 - precision: 0.9990 - recall: 0.9984 - val_loss: 0.0106 - val_accuracy: 0.9972 - val_auc: 0.9997 - val_precision: 0.9972 - val_recall: 0.9971
#
# Epoch 00034: val_loss did not improve from 0.00755
# Epoch 35/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0096 - accuracy: 0.9981 - auc: 1.0000 - precision: 0.9984 - recall: 0.9979 - val_loss: 0.0097 - val_accuracy: 0.9970 - val_auc: 0.9997 - val_precision: 0.9970 - val_recall: 0.9970
#
# Epoch 00035: val_loss did not improve from 0.00755
# Epoch 36/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0090 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9986 - recall: 0.9981 - val_loss: 0.0098 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9971
#
# Epoch 00036: val_loss did not improve from 0.00755
# Epoch 37/100
# 317/317 [==============================] - 1s 5ms/step - loss: 0.0095 - accuracy: 0.9978 - auc: 1.0000 - precision: 0.9984 - recall: 0.9975 - val_loss: 0.0317 - val_accuracy: 0.9920 - val_auc: 0.9996 - val_precision: 0.9929 - val_recall: 0.9913
#
# Epoch 00037: val_loss did not improve from 0.00755
# Epoch 38/100
# 317/317 [==============================] - 2s 5ms/step - loss: 0.0117 - accuracy: 0.9946 - auc: 1.0000 - precision: 0.9951 - recall: 0.9940 - val_loss: 0.0105 - val_accuracy: 0.9972 - val_auc: 0.9996 - val_precision: 0.9973 - val_recall: 0.9972
#
# Epoch 00038: val_loss did not improve from 0.00755
# Epoch 00038: early stopping
#               precision    recall  f1-score   support
#
#        Astro       1.00      1.00      1.00       603
#         Endo       0.80      1.00      0.89         4
#          Ext       1.00      1.00      1.00      2662
#          Inh       1.00      1.00      1.00      1694
#         LowQ       0.99      0.99      0.99        75
#        Micro       1.00      1.00      1.00       244
#           Nb       0.97      0.98      0.97        86
#          OPC       0.98      0.99      0.99       263
#        Oligo       1.00      1.00      1.00      2286
#
#     accuracy                           1.00      7917
#    macro avg       0.97      0.99      0.98      7917
# weighted avg       1.00      1.00      1.00      7917
#
# 248/248 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9972 - auc: 0.9999 - precision: 0.9973 - recall: 0.9972

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="Cell broad annotation", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="Cell broad annotation", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9962947368421052: Misclassification: 0.003705263157894767
#               precision    recall  f1-score   support
#
#        Astro       1.00      1.00      1.00       904
#         Endo       1.00      0.86      0.92         7
#          Ext       0.99      1.00      1.00      3993
#          Inh       1.00      0.99      0.99      2541
#         LowQ       0.98      0.98      0.98       112
#        Micro       1.00      1.00      1.00       365
#           Nb       0.98      0.97      0.97       128
#          OPC       1.00      1.00      1.00       395
#        Oligo       1.00      1.00      1.00      3430
#
#     accuracy                           1.00     11875
#    macro avg       0.99      0.98      0.98     11875
# weighted avg       1.00      1.00      1.00     11875

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="Cell broad annotation", top=3, figsize=(6,10))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 4162 genes across 39583 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  3844.737284183502

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  3338.3944194316864
