# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../../External_datasets/Healthy_foetal_organ_20pct.h5ad')

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 23054 genes across 42351 cells

# %%
obj
# Out:
# AnnData object with n_obs × n_vars = 42351 × 23054
#     obs: 'n_genes', 'patient', 'sample', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'organ', 'age', 'sorting', '# isolated cells', '# estimated cells', 'sangerID', 'batch', 'patient_sample', 'exp', 'n_counts', 'doublet_scores', 'S_score', 'G2M_score', 'phase', 'PHASE', 'Cell.Labels'
#     var: 'Ensembl', 'mean', 'std'
#     layers: 'counts', 'log', 'norm', 'scale'

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj)

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_HSC.txt")
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_liver.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="organ", pct=0.3)

# %%
obj
# Out:
# AnnData object with n_obs × n_vars = 42351 × 3961
#     obs: 'n_genes', 'patient', 'sample', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'organ', 'age', 'sorting', '# isolated cells', '# estimated cells', 'sangerID', 'batch', 'patient_sample', 'exp', 'n_counts', 'doublet_scores', 'S_score', 'G2M_score', 'phase', 'PHASE', 'Cell.Labels'
#     var: 'Ensembl', 'mean', 'std', 'general'
#     layers: 'counts', 'log', 'norm', 'scale'

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="organ", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.868165417707466

# %% [markdown]
# #### ensemble_learning

# %%
s2 = time.time()

# %%
clf = sf.ensemble_learning(obj, group_by="organ", classifier="RandomForest", balance=True, verbose=True)
# Out:
# Running with (Weighted) Random Forest
# Accuracy: 0.9801676307401723: Misclassification: 0.019832369259827676
#               precision    recall  f1-score   support
#
#       kidney       1.00      0.75      0.85       398
#        liver       0.98      1.00      0.99      5767
#         skin       0.98      0.97      0.98      2306
#
#     accuracy                           0.98      8471
#    macro avg       0.99      0.91      0.94      8471
# weighted avg       0.98      0.98      0.98      8471

# %% [markdown]
# #### gini_importance

# %%
selectedGenes, selectedGenes_dict = sf.gini_importance(obj, clf, group_by="organ", verbose=True, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="organ", genes=selectedGenes, classifier="KNN", balance=True, title="RF-KNN")
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9855973555800409: Misclassification: 0.014402644419959088
#               precision    recall  f1-score   support
#
#       kidney       0.95      0.88      0.91       596
#        liver       0.99      1.00      0.99      8651
#         skin       0.99      0.97      0.98      3459
#
#     accuracy                           0.99     12706
#    macro avg       0.98      0.95      0.96     12706
# weighted avg       0.99      0.99      0.99     12706

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="organ", group_by2=None, top=5, figsize=(4,12))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/RF_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 3128 genes across 42351 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  981.9588780403137

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  174.87066197395325
