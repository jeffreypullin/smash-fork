# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
#  * Initialising ...
# WARNING:tensorflow:From ../../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../../External_datasets/Healthy_foetal_organ_20pct.h5ad')

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 23054 genes across 42351 cells

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj)

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_HSC.txt")
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_liver.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="organ", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="organ", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.868165417707466

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
# num_classes = len(obj.obs["organ"].cat.categories)

# model = Sequential()

# model.add(Dense(1024, input_shape=(obj.X.shape[1],))) #1°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))
# model.add(Dropout(0.4))


# model.add(Dense(512, input_shape=(1024,))) #2°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))
# model.add(Dropout(0.1))


# model.add(Dense(128, input_shape=(512,))) #3°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))

# model.add(Dense(32, input_shape=(128,))) #4°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))

# model.add(Dense(num_classes, activation='softmax')) #output

# model.compile(loss=losses.categorical_crossentropy,
#               optimizer=optimizers.Adam(learning_rate=0.001, amsgrad=False),
#               metrics=['accuracy', 'AUC', 'Precision', 'Recall'])

# %%
sf.DNN(obj, group_by="organ", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                100128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 100,899
# Trainable params: 100,803
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 339/339 [==============================] - 3s 6ms/step - loss: 0.6073 - accuracy: 0.8859 - auc: 0.9710 - precision: 0.9673 - recall: 0.7128 - val_loss: 0.1654 - val_accuracy: 0.9843 - val_auc: 0.9995 - val_precision: 0.9909 - val_recall: 0.9779
#
# Epoch 00001: val_loss improved from inf to 0.16544, saving model to weights/best_model_organ.h5
# Epoch 2/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.1988 - accuracy: 0.9747 - auc: 0.9983 - precision: 0.9832 - recall: 0.9609 - val_loss: 0.0815 - val_accuracy: 0.9898 - val_auc: 0.9998 - val_precision: 0.9918 - val_recall: 0.9882
#
# Epoch 00002: val_loss improved from 0.16544 to 0.08153, saving model to weights/best_model_organ.h5
# Epoch 3/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0933 - accuracy: 0.9890 - auc: 0.9996 - precision: 0.9919 - recall: 0.9857 - val_loss: 0.0387 - val_accuracy: 0.9941 - val_auc: 0.9999 - val_precision: 0.9948 - val_recall: 0.9935
#
# Epoch 00003: val_loss improved from 0.08153 to 0.03872, saving model to weights/best_model_organ.h5
# Epoch 4/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0550 - accuracy: 0.9932 - auc: 0.9999 - precision: 0.9939 - recall: 0.9921 - val_loss: 0.0236 - val_accuracy: 0.9954 - val_auc: 0.9999 - val_precision: 0.9959 - val_recall: 0.9950
#
# Epoch 00004: val_loss improved from 0.03872 to 0.02358, saving model to weights/best_model_organ.h5
# Epoch 5/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0384 - accuracy: 0.9951 - auc: 0.9999 - precision: 0.9955 - recall: 0.9944 - val_loss: 0.0379 - val_accuracy: 0.9935 - val_auc: 0.9993 - val_precision: 0.9937 - val_recall: 0.9935
#
# Epoch 00005: val_loss did not improve from 0.02358
# Epoch 6/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0291 - accuracy: 0.9967 - auc: 1.0000 - precision: 0.9971 - recall: 0.9965 - val_loss: 0.0207 - val_accuracy: 0.9934 - val_auc: 0.9999 - val_precision: 0.9937 - val_recall: 0.9930
#
# Epoch 00006: val_loss improved from 0.02358 to 0.02067, saving model to weights/best_model_organ.h5
# Epoch 7/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0218 - accuracy: 0.9967 - auc: 1.0000 - precision: 0.9968 - recall: 0.9965 - val_loss: 0.0149 - val_accuracy: 0.9958 - val_auc: 0.9999 - val_precision: 0.9961 - val_recall: 0.9950
#
# Epoch 00007: val_loss improved from 0.02067 to 0.01490, saving model to weights/best_model_organ.h5
# Epoch 8/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0171 - accuracy: 0.9974 - auc: 1.0000 - precision: 0.9977 - recall: 0.9972 - val_loss: 0.0159 - val_accuracy: 0.9949 - val_auc: 0.9999 - val_precision: 0.9953 - val_recall: 0.9949
#
# Epoch 00008: val_loss did not improve from 0.01490
# Epoch 9/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0182 - accuracy: 0.9960 - auc: 0.9999 - precision: 0.9962 - recall: 0.9959 - val_loss: 0.0146 - val_accuracy: 0.9940 - val_auc: 1.0000 - val_precision: 0.9943 - val_recall: 0.9940
#
# Epoch 00009: val_loss improved from 0.01490 to 0.01457, saving model to weights/best_model_organ.h5
# Epoch 10/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0123 - accuracy: 0.9982 - auc: 1.0000 - precision: 0.9982 - recall: 0.9981 - val_loss: 0.0178 - val_accuracy: 0.9946 - val_auc: 0.9999 - val_precision: 0.9946 - val_recall: 0.9943
#
# Epoch 00010: val_loss did not improve from 0.01457
# Epoch 11/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0100 - accuracy: 0.9988 - auc: 1.0000 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0139 - val_accuracy: 0.9960 - val_auc: 0.9999 - val_precision: 0.9960 - val_recall: 0.9958
#
# Epoch 00011: val_loss improved from 0.01457 to 0.01387, saving model to weights/best_model_organ.h5
# Epoch 12/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9978 - recall: 0.9977 - val_loss: 0.0198 - val_accuracy: 0.9945 - val_auc: 0.9993 - val_precision: 0.9946 - val_recall: 0.9943
#
# Epoch 00012: val_loss did not improve from 0.01387
# Epoch 13/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0113 - accuracy: 0.9965 - auc: 1.0000 - precision: 0.9966 - recall: 0.9963 - val_loss: 0.0136 - val_accuracy: 0.9952 - val_auc: 0.9998 - val_precision: 0.9953 - val_recall: 0.9952
#
# Epoch 00013: val_loss improved from 0.01387 to 0.01362, saving model to weights/best_model_organ.h5
# Epoch 14/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0070 - accuracy: 0.9986 - auc: 1.0000 - precision: 0.9987 - recall: 0.9986 - val_loss: 0.0134 - val_accuracy: 0.9963 - val_auc: 1.0000 - val_precision: 0.9965 - val_recall: 0.9962
#
# Epoch 00014: val_loss improved from 0.01362 to 0.01340, saving model to weights/best_model_organ.h5
# Epoch 15/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0067 - accuracy: 0.9989 - auc: 1.0000 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.0157 - val_accuracy: 0.9953 - val_auc: 0.9996 - val_precision: 0.9955 - val_recall: 0.9952
#
# Epoch 00015: val_loss did not improve from 0.01340
# Epoch 16/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9983 - auc: 1.0000 - precision: 0.9983 - recall: 0.9983 - val_loss: 0.0312 - val_accuracy: 0.9898 - val_auc: 0.9993 - val_precision: 0.9900 - val_recall: 0.9898
#
# Epoch 00016: val_loss did not improve from 0.01340
# Epoch 17/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0064 - accuracy: 0.9987 - auc: 1.0000 - precision: 0.9987 - recall: 0.9987 - val_loss: 0.0155 - val_accuracy: 0.9956 - val_auc: 0.9997 - val_precision: 0.9956 - val_recall: 0.9956
#
# Epoch 00017: val_loss did not improve from 0.01340
# Epoch 18/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0047 - accuracy: 0.9991 - auc: 1.0000 - precision: 0.9991 - recall: 0.9991 - val_loss: 0.0162 - val_accuracy: 0.9948 - val_auc: 0.9994 - val_precision: 0.9949 - val_recall: 0.9948
#
# Epoch 00018: val_loss did not improve from 0.01340
# Epoch 19/100
# 339/339 [==============================] - 1s 4ms/step - loss: 0.0046 - accuracy: 0.9987 - auc: 1.0000 - precision: 0.9987 - recall: 0.9987 - val_loss: 0.0173 - val_accuracy: 0.9948 - val_auc: 0.9993 - val_precision: 0.9948 - val_recall: 0.9947
#
# Epoch 00019: val_loss did not improve from 0.01340
# Epoch 00019: early stopping
#               precision    recall  f1-score   support
#
#       kidney       0.94      0.98      0.96       398
#        liver       1.00      1.00      1.00      5767
#         skin       0.99      0.99      0.99      2306
#
#     accuracy                           0.99      8471
#    macro avg       0.98      0.99      0.98      8471
# weighted avg       0.99      0.99      0.99      8471
#
# 265/265 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9963 - auc: 1.0000 - precision: 0.9965 - recall: 0.9962

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="organ", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="organ", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9885880686289942: Misclassification: 0.011411931371005823
#               precision    recall  f1-score   support
#
#       kidney       0.98      0.90      0.94       596
#        liver       0.99      1.00      0.99      8651
#         skin       0.99      0.98      0.98      3459
#
#     accuracy                           0.99     12706
#    macro avg       0.99      0.96      0.97     12706
# weighted avg       0.99      0.99      0.99     12706

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="organ", group_by2=None, top=5, figsize=(4,12))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 3128 genes across 42351 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  1056.910266160965

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  726.0128498077393
