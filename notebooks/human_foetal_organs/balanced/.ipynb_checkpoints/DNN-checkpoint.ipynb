# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../../External_datasets/Healthy_foetal_organ_9933.h5ad')

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 23054 genes across 29799 cells

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj)

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_HSC.txt")
obj = sf.remove_housekeepingenes(obj, path="../../data/house_keeping_genes_human_foetal_liver.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="organ", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="organ", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.9160369437447523

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
# num_classes = len(obj.obs["organ"].cat.categories)

# model = Sequential()

# model.add(Dense(1024, input_shape=(obj.X.shape[1],))) #1°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))
# model.add(Dropout(0.4))


# model.add(Dense(512, input_shape=(1024,))) #2°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))
# model.add(Dropout(0.1))


# model.add(Dense(128, input_shape=(512,))) #3°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))

# model.add(Dense(32, input_shape=(128,))) #4°layer
# model.add(BatchNormalization())
# model.add(Activation('sigmoid'))

# model.add(Dense(num_classes, activation='softmax')) #output

# model.compile(loss=losses.categorical_crossentropy,
#               optimizer=optimizers.Adam(learning_rate=0.001, amsgrad=False),
#               metrics=['accuracy', 'AUC', 'Precision', 'Recall'])

# %%
sf.DNN(obj, group_by="organ", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                104768
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 105,539
# Trainable params: 105,443
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 239/239 [==============================] - 3s 7ms/step - loss: 0.6678 - accuracy: 0.8189 - auc: 0.9274 - precision: 0.9164 - recall: 0.6107 - val_loss: 0.2288 - val_accuracy: 0.9879 - val_auc: 0.9996 - val_precision: 0.9920 - val_recall: 0.9789
#
# Epoch 00001: val_loss improved from inf to 0.22878, saving model to weights/best_model_organ.h5
# Epoch 2/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.2656 - accuracy: 0.9745 - auc: 0.9981 - precision: 0.9871 - recall: 0.9521 - val_loss: 0.1075 - val_accuracy: 0.9904 - val_auc: 0.9997 - val_precision: 0.9919 - val_recall: 0.9883
#
# Epoch 00002: val_loss improved from 0.22878 to 0.10751, saving model to weights/best_model_organ.h5
# Epoch 3/100
# 239/239 [==============================] - 1s 5ms/step - loss: 0.1416 - accuracy: 0.9858 - auc: 0.9994 - precision: 0.9904 - recall: 0.9781 - val_loss: 0.0706 - val_accuracy: 0.9899 - val_auc: 0.9997 - val_precision: 0.9911 - val_recall: 0.9878
#
# Epoch 00003: val_loss improved from 0.10751 to 0.07063, saving model to weights/best_model_organ.h5
# Epoch 4/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0872 - accuracy: 0.9915 - auc: 0.9998 - precision: 0.9937 - recall: 0.9891 - val_loss: 0.0551 - val_accuracy: 0.9889 - val_auc: 0.9997 - val_precision: 0.9899 - val_recall: 0.9884
#
# Epoch 00004: val_loss improved from 0.07063 to 0.05510, saving model to weights/best_model_organ.h5
# Epoch 5/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0633 - accuracy: 0.9922 - auc: 0.9998 - precision: 0.9939 - recall: 0.9905 - val_loss: 0.0449 - val_accuracy: 0.9898 - val_auc: 0.9997 - val_precision: 0.9904 - val_recall: 0.9889
#
# Epoch 00005: val_loss improved from 0.05510 to 0.04493, saving model to weights/best_model_organ.h5
# Epoch 6/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0447 - accuracy: 0.9960 - auc: 0.9999 - precision: 0.9965 - recall: 0.9948 - val_loss: 0.0348 - val_accuracy: 0.9898 - val_auc: 0.9997 - val_precision: 0.9908 - val_recall: 0.9888
#
# Epoch 00006: val_loss improved from 0.04493 to 0.03482, saving model to weights/best_model_organ.h5
# Epoch 7/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0325 - accuracy: 0.9968 - auc: 1.0000 - precision: 0.9970 - recall: 0.9962 - val_loss: 0.0306 - val_accuracy: 0.9906 - val_auc: 0.9997 - val_precision: 0.9913 - val_recall: 0.9904
#
# Epoch 00007: val_loss improved from 0.03482 to 0.03061, saving model to weights/best_model_organ.h5
# Epoch 8/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0257 - accuracy: 0.9973 - auc: 1.0000 - precision: 0.9976 - recall: 0.9968 - val_loss: 0.0312 - val_accuracy: 0.9896 - val_auc: 0.9995 - val_precision: 0.9903 - val_recall: 0.9891
#
# Epoch 00008: val_loss did not improve from 0.03061
# Epoch 9/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0234 - accuracy: 0.9961 - auc: 1.0000 - precision: 0.9964 - recall: 0.9957 - val_loss: 0.0301 - val_accuracy: 0.9906 - val_auc: 0.9996 - val_precision: 0.9908 - val_recall: 0.9903
#
# Epoch 00009: val_loss improved from 0.03061 to 0.03007, saving model to weights/best_model_organ.h5
# Epoch 10/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0203 - accuracy: 0.9972 - auc: 1.0000 - precision: 0.9975 - recall: 0.9970 - val_loss: 0.0316 - val_accuracy: 0.9889 - val_auc: 0.9996 - val_precision: 0.9891 - val_recall: 0.9889
#
# Epoch 00010: val_loss did not improve from 0.03007
# Epoch 11/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0174 - accuracy: 0.9972 - auc: 1.0000 - precision: 0.9973 - recall: 0.9970 - val_loss: 0.0275 - val_accuracy: 0.9911 - val_auc: 0.9994 - val_precision: 0.9916 - val_recall: 0.9901
#
# Epoch 00011: val_loss improved from 0.03007 to 0.02754, saving model to weights/best_model_organ.h5
# Epoch 12/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - auc: 1.0000 - precision: 0.9982 - recall: 0.9979 - val_loss: 0.0286 - val_accuracy: 0.9906 - val_auc: 0.9995 - val_precision: 0.9909 - val_recall: 0.9901
#
# Epoch 00012: val_loss did not improve from 0.02754
# Epoch 13/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0122 - accuracy: 0.9981 - auc: 1.0000 - precision: 0.9982 - recall: 0.9980 - val_loss: 0.0272 - val_accuracy: 0.9908 - val_auc: 0.9996 - val_precision: 0.9909 - val_recall: 0.9906
#
# Epoch 00013: val_loss improved from 0.02754 to 0.02719, saving model to weights/best_model_organ.h5
# Epoch 14/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0102 - accuracy: 0.9986 - auc: 1.0000 - precision: 0.9987 - recall: 0.9986 - val_loss: 0.0277 - val_accuracy: 0.9899 - val_auc: 0.9994 - val_precision: 0.9903 - val_recall: 0.9894
#
# Epoch 00014: val_loss did not improve from 0.02719
# Epoch 15/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0095 - accuracy: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9980 - val_loss: 0.0275 - val_accuracy: 0.9914 - val_auc: 0.9993 - val_precision: 0.9918 - val_recall: 0.9914
#
# Epoch 00015: val_loss did not improve from 0.02719
# Epoch 16/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0096 - accuracy: 0.9978 - auc: 1.0000 - precision: 0.9979 - recall: 0.9977 - val_loss: 0.0364 - val_accuracy: 0.9893 - val_auc: 0.9992 - val_precision: 0.9898 - val_recall: 0.9886
#
# Epoch 00016: val_loss did not improve from 0.02719
# Epoch 17/100
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0085 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9984 - recall: 0.9982 - val_loss: 0.0318 - val_accuracy: 0.9901 - val_auc: 0.9989 - val_precision: 0.9904 - val_recall: 0.9899
#
# Epoch 00017: val_loss did not improve from 0.02719
# Epoch 18/100
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0084 - accuracy: 0.9980 - auc: 1.0000 - precision: 0.9980 - recall: 0.9980 - val_loss: 0.0318 - val_accuracy: 0.9901 - val_auc: 0.9992 - val_precision: 0.9906 - val_recall: 0.9901
#
# Epoch 00018: val_loss did not improve from 0.02719
# Epoch 00018: early stopping
#               precision    recall  f1-score   support
#
#       kidney       0.98      0.99      0.99      1986
#        liver       0.99      1.00      1.00      1987
#         skin       0.99      0.98      0.99      1987
#
#     accuracy                           0.99      5960
#    macro avg       0.99      0.99      0.99      5960
# weighted avg       0.99      0.99      0.99      5960
#
# 187/187 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 0.9908 - auc: 0.9996 - precision: 0.9909 - recall: 0.9906

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="organ", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="organ", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9751677852348993: Misclassification: 0.02483221476510067
#               precision    recall  f1-score   support
#
#       kidney       0.96      0.97      0.97      2980
#        liver       0.98      0.99      0.98      2980
#         skin       0.98      0.96      0.97      2980
#
#     accuracy                           0.98      8940
#    macro avg       0.98      0.98      0.98      8940
# weighted avg       0.98      0.98      0.98      8940

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="organ", group_by2=None, top=5, figsize=(4,12))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 3273 genes across 29799 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  594.7504982948303

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  392.35547280311584
