# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
import smashpy
sf = smashpy.smashpy()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../External_datasets/CITEseq.h5ad')

# %%
obj.raw = obj.copy()
obj.layers["nome"] = obj.X.copy()
obj.layers["log"] = obj.X.copy()
obj.layers["scale"] = obj.X.copy()

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 500 genes across 8617 cells

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
sf.DNN(obj, group_by="labels", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                16032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                221
# =================================================================
# Total params: 16,973
# Trainable params: 16,877
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 69/69 [==============================] - 2s 16ms/step - loss: 2.4901 - accuracy: 0.1058 - auc: 0.6736 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.2747 - val_accuracy: 0.3231 - val_auc: 0.8788 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 2.27465, saving model to weights/best_model_labels.h5
# Epoch 2/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0216 - accuracy: 0.3613 - auc: 0.8241 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0878 - val_accuracy: 0.7628 - val_auc: 0.9581 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 2.27465 to 2.08779, saving model to weights/best_model_labels.h5
# Epoch 3/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9074 - accuracy: 0.4593 - auc: 0.8604 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9069 - val_accuracy: 0.8428 - val_auc: 0.9798 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 2.08779 to 1.90691, saving model to weights/best_model_labels.h5
# Epoch 4/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.8576 - accuracy: 0.5265 - auc: 0.8885 - precision: 0.1429 - recall: 2.1886e-05 - val_loss: 1.7324 - val_accuracy: 0.8654 - val_auc: 0.9872 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss improved from 1.90691 to 1.73245, saving model to weights/best_model_labels.h5
# Epoch 5/100
# 69/69 [==============================] - 1s 17ms/step - loss: 1.6808 - accuracy: 0.5997 - auc: 0.9229 - precision: 0.9000 - recall: 5.3311e-04 - val_loss: 1.5801 - val_accuracy: 0.8857 - val_auc: 0.9912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss improved from 1.73245 to 1.58011, saving model to weights/best_model_labels.h5
# Epoch 6/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.5673 - accuracy: 0.6385 - auc: 0.9372 - precision: 0.9714 - recall: 0.0113 - val_loss: 1.4865 - val_accuracy: 0.8701 - val_auc: 0.9909 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00006: val_loss improved from 1.58011 to 1.48648, saving model to weights/best_model_labels.h5
# Epoch 7/100
# 69/69 [==============================] - 1s 19ms/step - loss: 1.4103 - accuracy: 0.6627 - auc: 0.9468 - precision: 1.0000 - recall: 0.0281 - val_loss: 1.3716 - val_accuracy: 0.8759 - val_auc: 0.9924 - val_precision: 1.0000 - val_recall: 0.0441
#
# Epoch 00007: val_loss improved from 1.48648 to 1.37157, saving model to weights/best_model_labels.h5
# Epoch 8/100
# 69/69 [==============================] - 2s 22ms/step - loss: 1.3495 - accuracy: 0.6750 - auc: 0.9528 - precision: 0.9982 - recall: 0.0556 - val_loss: 1.2863 - val_accuracy: 0.8840 - val_auc: 0.9927 - val_precision: 1.0000 - val_recall: 0.1056
#
# Epoch 00008: val_loss improved from 1.37157 to 1.28627, saving model to weights/best_model_labels.h5
# Epoch 9/100
# 69/69 [==============================] - 1s 19ms/step - loss: 1.2836 - accuracy: 0.7055 - auc: 0.9588 - precision: 1.0000 - recall: 0.0915 - val_loss: 1.1967 - val_accuracy: 0.8881 - val_auc: 0.9930 - val_precision: 0.9932 - val_recall: 0.1705
#
# Epoch 00009: val_loss improved from 1.28627 to 1.19674, saving model to weights/best_model_labels.h5
# Epoch 10/100
# 69/69 [==============================] - 1s 21ms/step - loss: 1.1853 - accuracy: 0.7270 - auc: 0.9670 - precision: 0.9919 - recall: 0.1183 - val_loss: 1.1246 - val_accuracy: 0.8886 - val_auc: 0.9936 - val_precision: 0.9944 - val_recall: 0.2048
#
# Epoch 00010: val_loss improved from 1.19674 to 1.12462, saving model to weights/best_model_labels.h5
# Epoch 11/100
# 69/69 [==============================] - 1s 20ms/step - loss: 1.1027 - accuracy: 0.7413 - auc: 0.9709 - precision: 0.9922 - recall: 0.1536 - val_loss: 1.0296 - val_accuracy: 0.8921 - val_auc: 0.9939 - val_precision: 0.9950 - val_recall: 0.2297
#
# Epoch 00011: val_loss improved from 1.12462 to 1.02960, saving model to weights/best_model_labels.h5
# Epoch 12/100
# 69/69 [==============================] - 1s 20ms/step - loss: 0.9795 - accuracy: 0.7342 - auc: 0.9718 - precision: 0.9925 - recall: 0.2074 - val_loss: 0.9678 - val_accuracy: 0.8910 - val_auc: 0.9938 - val_precision: 0.9870 - val_recall: 0.2651
#
# Epoch 00012: val_loss improved from 1.02960 to 0.96784, saving model to weights/best_model_labels.h5
# Epoch 13/100
# 69/69 [==============================] - 1s 21ms/step - loss: 0.9628 - accuracy: 0.7731 - auc: 0.9770 - precision: 0.9855 - recall: 0.2404 - val_loss: 0.8998 - val_accuracy: 0.8921 - val_auc: 0.9938 - val_precision: 0.9874 - val_recall: 0.3190
#
# Epoch 00013: val_loss improved from 0.96784 to 0.89977, saving model to weights/best_model_labels.h5
# Epoch 14/100
# 69/69 [==============================] - 1s 18ms/step - loss: 0.9245 - accuracy: 0.7747 - auc: 0.9793 - precision: 0.9849 - recall: 0.2822 - val_loss: 0.8484 - val_accuracy: 0.8834 - val_auc: 0.9937 - val_precision: 0.9878 - val_recall: 0.3753
#
# Epoch 00014: val_loss improved from 0.89977 to 0.84843, saving model to weights/best_model_labels.h5
# Epoch 15/100
# 69/69 [==============================] - 1s 22ms/step - loss: 0.8348 - accuracy: 0.7756 - auc: 0.9795 - precision: 0.9807 - recall: 0.3398 - val_loss: 0.8218 - val_accuracy: 0.8741 - val_auc: 0.9930 - val_precision: 0.9767 - val_recall: 0.4130
#
# Epoch 00015: val_loss improved from 0.84843 to 0.82182, saving model to weights/best_model_labels.h5
# Epoch 16/100
# 69/69 [==============================] - 1s 21ms/step - loss: 0.8104 - accuracy: 0.7746 - auc: 0.9804 - precision: 0.9736 - recall: 0.3678 - val_loss: 0.7466 - val_accuracy: 0.8933 - val_auc: 0.9946 - val_precision: 0.9805 - val_recall: 0.4959
#
# Epoch 00016: val_loss improved from 0.82182 to 0.74663, saving model to weights/best_model_labels.h5
# Epoch 17/100
# 69/69 [==============================] - 1s 18ms/step - loss: 0.7126 - accuracy: 0.8027 - auc: 0.9849 - precision: 0.9788 - recall: 0.4199 - val_loss: 0.7168 - val_accuracy: 0.8846 - val_auc: 0.9942 - val_precision: 0.9727 - val_recall: 0.5365
#
# Epoch 00017: val_loss improved from 0.74663 to 0.71676, saving model to weights/best_model_labels.h5
# Epoch 18/100
# 69/69 [==============================] - 1s 19ms/step - loss: 0.7058 - accuracy: 0.7934 - auc: 0.9847 - precision: 0.9573 - recall: 0.4387 - val_loss: 0.6235 - val_accuracy: 0.9049 - val_auc: 0.9959 - val_precision: 0.9750 - val_recall: 0.6560
#
# Epoch 00018: val_loss improved from 0.71676 to 0.62348, saving model to weights/best_model_labels.h5
# Epoch 19/100
# 69/69 [==============================] - 1s 21ms/step - loss: 0.6491 - accuracy: 0.8164 - auc: 0.9878 - precision: 0.9622 - recall: 0.5183 - val_loss: 0.6194 - val_accuracy: 0.8944 - val_auc: 0.9951 - val_precision: 0.9636 - val_recall: 0.6763
#
# Epoch 00019: val_loss improved from 0.62348 to 0.61936, saving model to weights/best_model_labels.h5
# Epoch 20/100
# 69/69 [==============================] - 1s 19ms/step - loss: 0.5964 - accuracy: 0.8175 - auc: 0.9867 - precision: 0.9555 - recall: 0.5427 - val_loss: 0.5747 - val_accuracy: 0.9002 - val_auc: 0.9957 - val_precision: 0.9624 - val_recall: 0.7135
#
# Epoch 00020: val_loss improved from 0.61936 to 0.57471, saving model to weights/best_model_labels.h5
# Epoch 21/100
# 69/69 [==============================] - 1s 7ms/step - loss: 0.5832 - accuracy: 0.8188 - auc: 0.9880 - precision: 0.9504 - recall: 0.5680 - val_loss: 0.5703 - val_accuracy: 0.8898 - val_auc: 0.9950 - val_precision: 0.9497 - val_recall: 0.7233
#
# Epoch 00021: val_loss improved from 0.57471 to 0.57030, saving model to weights/best_model_labels.h5
# Epoch 22/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.5520 - accuracy: 0.8311 - auc: 0.9892 - precision: 0.9467 - recall: 0.6037 - val_loss: 0.5368 - val_accuracy: 0.8857 - val_auc: 0.9952 - val_precision: 0.9407 - val_recall: 0.7454
#
# Epoch 00022: val_loss improved from 0.57030 to 0.53685, saving model to weights/best_model_labels.h5
# Epoch 23/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.5198 - accuracy: 0.8225 - auc: 0.9890 - precision: 0.9348 - recall: 0.6207 - val_loss: 0.5039 - val_accuracy: 0.9008 - val_auc: 0.9959 - val_precision: 0.9455 - val_recall: 0.7848
#
# Epoch 00023: val_loss improved from 0.53685 to 0.50385, saving model to weights/best_model_labels.h5
# Epoch 24/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.4794 - accuracy: 0.8330 - auc: 0.9903 - precision: 0.9328 - recall: 0.6416 - val_loss: 0.4962 - val_accuracy: 0.8927 - val_auc: 0.9954 - val_precision: 0.9352 - val_recall: 0.7865
#
# Epoch 00024: val_loss improved from 0.50385 to 0.49624, saving model to weights/best_model_labels.h5
# Epoch 25/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.4598 - accuracy: 0.8210 - auc: 0.9897 - precision: 0.9251 - recall: 0.6396 - val_loss: 0.4750 - val_accuracy: 0.8933 - val_auc: 0.9956 - val_precision: 0.9343 - val_recall: 0.8005
#
# Epoch 00025: val_loss improved from 0.49624 to 0.47499, saving model to weights/best_model_labels.h5
# Epoch 26/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.4353 - accuracy: 0.8407 - auc: 0.9911 - precision: 0.9345 - recall: 0.6804 - val_loss: 0.4433 - val_accuracy: 0.8991 - val_auc: 0.9959 - val_precision: 0.9334 - val_recall: 0.8295
#
# Epoch 00026: val_loss improved from 0.47499 to 0.44327, saving model to weights/best_model_labels.h5
# Epoch 27/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.4127 - accuracy: 0.8425 - auc: 0.9920 - precision: 0.9314 - recall: 0.7022 - val_loss: 0.4327 - val_accuracy: 0.8857 - val_auc: 0.9957 - val_precision: 0.9255 - val_recall: 0.8289
#
# Epoch 00027: val_loss improved from 0.44327 to 0.43270, saving model to weights/best_model_labels.h5
# Epoch 28/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.4021 - accuracy: 0.8438 - auc: 0.9922 - precision: 0.9230 - recall: 0.7115 - val_loss: 0.4286 - val_accuracy: 0.8904 - val_auc: 0.9957 - val_precision: 0.9302 - val_recall: 0.8347
#
# Epoch 00028: val_loss improved from 0.43270 to 0.42865, saving model to weights/best_model_labels.h5
# Epoch 29/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3874 - accuracy: 0.8508 - auc: 0.9925 - precision: 0.9283 - recall: 0.7231 - val_loss: 0.4094 - val_accuracy: 0.8956 - val_auc: 0.9960 - val_precision: 0.9283 - val_recall: 0.8416
#
# Epoch 00029: val_loss improved from 0.42865 to 0.40940, saving model to weights/best_model_labels.h5
# Epoch 30/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.8652 - auc: 0.9939 - precision: 0.9257 - recall: 0.7541 - val_loss: 0.3822 - val_accuracy: 0.9008 - val_auc: 0.9965 - val_precision: 0.9295 - val_recall: 0.8567
#
# Epoch 00030: val_loss improved from 0.40940 to 0.38219, saving model to weights/best_model_labels.h5
# Epoch 31/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3463 - accuracy: 0.8623 - auc: 0.9937 - precision: 0.9216 - recall: 0.7597 - val_loss: 0.3777 - val_accuracy: 0.9002 - val_auc: 0.9962 - val_precision: 0.9259 - val_recall: 0.8625
#
# Epoch 00031: val_loss improved from 0.38219 to 0.37774, saving model to weights/best_model_labels.h5
# Epoch 32/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3283 - accuracy: 0.8603 - auc: 0.9936 - precision: 0.9172 - recall: 0.7619 - val_loss: 0.3538 - val_accuracy: 0.9078 - val_auc: 0.9965 - val_precision: 0.9316 - val_recall: 0.8689
#
# Epoch 00032: val_loss improved from 0.37774 to 0.35383, saving model to weights/best_model_labels.h5
# Epoch 33/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.8710 - auc: 0.9942 - precision: 0.9276 - recall: 0.7731 - val_loss: 0.3326 - val_accuracy: 0.9066 - val_auc: 0.9968 - val_precision: 0.9367 - val_recall: 0.8753
#
# Epoch 00033: val_loss improved from 0.35383 to 0.33261, saving model to weights/best_model_labels.h5
# Epoch 34/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3227 - accuracy: 0.8825 - auc: 0.9951 - precision: 0.9279 - recall: 0.7978 - val_loss: 0.3565 - val_accuracy: 0.8985 - val_auc: 0.9961 - val_precision: 0.9216 - val_recall: 0.8660
#
# Epoch 00034: val_loss did not improve from 0.33261
# Epoch 35/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2928 - accuracy: 0.8760 - auc: 0.9946 - precision: 0.9257 - recall: 0.7950 - val_loss: 0.3423 - val_accuracy: 0.9037 - val_auc: 0.9964 - val_precision: 0.9295 - val_recall: 0.8724
#
# Epoch 00035: val_loss did not improve from 0.33261
# Epoch 36/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8782 - auc: 0.9941 - precision: 0.9240 - recall: 0.7940 - val_loss: 0.3080 - val_accuracy: 0.9124 - val_auc: 0.9970 - val_precision: 0.9303 - val_recall: 0.8828
#
# Epoch 00036: val_loss improved from 0.33261 to 0.30797, saving model to weights/best_model_labels.h5
# Epoch 37/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.8785 - auc: 0.9953 - precision: 0.9235 - recall: 0.8091 - val_loss: 0.2991 - val_accuracy: 0.9124 - val_auc: 0.9971 - val_precision: 0.9322 - val_recall: 0.8927
#
# Epoch 00037: val_loss improved from 0.30797 to 0.29907, saving model to weights/best_model_labels.h5
# Epoch 38/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8938 - auc: 0.9957 - precision: 0.9311 - recall: 0.8230 - val_loss: 0.2979 - val_accuracy: 0.9130 - val_auc: 0.9970 - val_precision: 0.9286 - val_recall: 0.8904
#
# Epoch 00038: val_loss improved from 0.29907 to 0.29794, saving model to weights/best_model_labels.h5
# Epoch 39/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.8819 - auc: 0.9955 - precision: 0.9300 - recall: 0.8251 - val_loss: 0.2932 - val_accuracy: 0.9142 - val_auc: 0.9971 - val_precision: 0.9314 - val_recall: 0.8904
#
# Epoch 00039: val_loss improved from 0.29794 to 0.29322, saving model to weights/best_model_labels.h5
# Epoch 40/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2434 - accuracy: 0.8946 - auc: 0.9958 - precision: 0.9289 - recall: 0.8361 - val_loss: 0.2814 - val_accuracy: 0.9153 - val_auc: 0.9972 - val_precision: 0.9296 - val_recall: 0.8962
#
# Epoch 00040: val_loss improved from 0.29322 to 0.28137, saving model to weights/best_model_labels.h5
# Epoch 41/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2400 - accuracy: 0.8964 - auc: 0.9959 - precision: 0.9278 - recall: 0.8356 - val_loss: 0.2816 - val_accuracy: 0.9101 - val_auc: 0.9971 - val_precision: 0.9296 - val_recall: 0.8956
#
# Epoch 00041: val_loss did not improve from 0.28137
# Epoch 42/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2346 - accuracy: 0.9037 - auc: 0.9962 - precision: 0.9394 - recall: 0.8519 - val_loss: 0.2864 - val_accuracy: 0.9113 - val_auc: 0.9970 - val_precision: 0.9285 - val_recall: 0.8892
#
# Epoch 00042: val_loss did not improve from 0.28137
# Epoch 43/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.9013 - auc: 0.9965 - precision: 0.9353 - recall: 0.8507 - val_loss: 0.2745 - val_accuracy: 0.9142 - val_auc: 0.9971 - val_precision: 0.9302 - val_recall: 0.8973
#
# Epoch 00043: val_loss improved from 0.28137 to 0.27447, saving model to weights/best_model_labels.h5
# Epoch 44/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2129 - accuracy: 0.8920 - auc: 0.9958 - precision: 0.9248 - recall: 0.8422 - val_loss: 0.2702 - val_accuracy: 0.9182 - val_auc: 0.9972 - val_precision: 0.9323 - val_recall: 0.9026
#
# Epoch 00044: val_loss improved from 0.27447 to 0.27021, saving model to weights/best_model_labels.h5
# Epoch 45/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.8995 - auc: 0.9964 - precision: 0.9331 - recall: 0.8564 - val_loss: 0.2507 - val_accuracy: 0.9252 - val_auc: 0.9975 - val_precision: 0.9416 - val_recall: 0.9078
#
# Epoch 00045: val_loss improved from 0.27021 to 0.25071, saving model to weights/best_model_labels.h5
# Epoch 46/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.9082 - auc: 0.9967 - precision: 0.9332 - recall: 0.8642 - val_loss: 0.2548 - val_accuracy: 0.9188 - val_auc: 0.9973 - val_precision: 0.9360 - val_recall: 0.9072
#
# Epoch 00046: val_loss did not improve from 0.25071
# Epoch 47/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1940 - accuracy: 0.9079 - auc: 0.9972 - precision: 0.9367 - recall: 0.8660 - val_loss: 0.2717 - val_accuracy: 0.9101 - val_auc: 0.9967 - val_precision: 0.9220 - val_recall: 0.8979
#
# Epoch 00047: val_loss did not improve from 0.25071
# Epoch 48/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1956 - accuracy: 0.9061 - auc: 0.9968 - precision: 0.9304 - recall: 0.8656 - val_loss: 0.2385 - val_accuracy: 0.9263 - val_auc: 0.9973 - val_precision: 0.9352 - val_recall: 0.9130
#
# Epoch 00048: val_loss improved from 0.25071 to 0.23850, saving model to weights/best_model_labels.h5
# Epoch 49/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2027 - accuracy: 0.9087 - auc: 0.9971 - precision: 0.9353 - recall: 0.8699 - val_loss: 0.2345 - val_accuracy: 0.9287 - val_auc: 0.9973 - val_precision: 0.9411 - val_recall: 0.9171
#
# Epoch 00049: val_loss improved from 0.23850 to 0.23449, saving model to weights/best_model_labels.h5
# Epoch 50/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1986 - accuracy: 0.9121 - auc: 0.9972 - precision: 0.9376 - recall: 0.8747 - val_loss: 0.2526 - val_accuracy: 0.9200 - val_auc: 0.9969 - val_precision: 0.9326 - val_recall: 0.9072
#
# Epoch 00050: val_loss did not improve from 0.23449
# Epoch 51/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1779 - accuracy: 0.9122 - auc: 0.9970 - precision: 0.9342 - recall: 0.8758 - val_loss: 0.2574 - val_accuracy: 0.9205 - val_auc: 0.9969 - val_precision: 0.9346 - val_recall: 0.9037
#
# Epoch 00051: val_loss did not improve from 0.23449
# Epoch 52/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.9024 - auc: 0.9972 - precision: 0.9332 - recall: 0.8704 - val_loss: 0.2492 - val_accuracy: 0.9211 - val_auc: 0.9970 - val_precision: 0.9310 - val_recall: 0.9072
#
# Epoch 00052: val_loss did not improve from 0.23449
# Epoch 53/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1676 - accuracy: 0.9154 - auc: 0.9973 - precision: 0.9393 - recall: 0.8854 - val_loss: 0.2366 - val_accuracy: 0.9246 - val_auc: 0.9972 - val_precision: 0.9338 - val_recall: 0.9165
#
# Epoch 00053: val_loss did not improve from 0.23449
# Epoch 54/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9029 - auc: 0.9967 - precision: 0.9258 - recall: 0.8707 - val_loss: 0.2337 - val_accuracy: 0.9246 - val_auc: 0.9973 - val_precision: 0.9323 - val_recall: 0.9188
#
# Epoch 00054: val_loss improved from 0.23449 to 0.23367, saving model to weights/best_model_labels.h5
# Epoch 55/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1895 - accuracy: 0.9060 - auc: 0.9970 - precision: 0.9330 - recall: 0.8801 - val_loss: 0.2382 - val_accuracy: 0.9234 - val_auc: 0.9971 - val_precision: 0.9318 - val_recall: 0.9113
#
# Epoch 00055: val_loss did not improve from 0.23367
# Epoch 56/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1900 - accuracy: 0.9150 - auc: 0.9975 - precision: 0.9409 - recall: 0.8892 - val_loss: 0.2253 - val_accuracy: 0.9263 - val_auc: 0.9969 - val_precision: 0.9360 - val_recall: 0.9165
#
# Epoch 00056: val_loss improved from 0.23367 to 0.22525, saving model to weights/best_model_labels.h5
# Epoch 57/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1622 - accuracy: 0.9255 - auc: 0.9978 - precision: 0.9441 - recall: 0.8983 - val_loss: 0.2123 - val_accuracy: 0.9327 - val_auc: 0.9968 - val_precision: 0.9398 - val_recall: 0.9229
#
# Epoch 00057: val_loss improved from 0.22525 to 0.21227, saving model to weights/best_model_labels.h5
# Epoch 58/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1583 - accuracy: 0.9212 - auc: 0.9979 - precision: 0.9425 - recall: 0.8977 - val_loss: 0.2282 - val_accuracy: 0.9275 - val_auc: 0.9968 - val_precision: 0.9346 - val_recall: 0.9205
#
# Epoch 00058: val_loss did not improve from 0.21227
# Epoch 59/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9258 - auc: 0.9979 - precision: 0.9428 - recall: 0.9063 - val_loss: 0.2272 - val_accuracy: 0.9281 - val_auc: 0.9968 - val_precision: 0.9375 - val_recall: 0.9229
#
# Epoch 00059: val_loss did not improve from 0.21227
# Epoch 60/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9227 - auc: 0.9980 - precision: 0.9411 - recall: 0.9016 - val_loss: 0.2248 - val_accuracy: 0.9298 - val_auc: 0.9969 - val_precision: 0.9354 - val_recall: 0.9240
#
# Epoch 00060: val_loss did not improve from 0.21227
# Epoch 61/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9274 - auc: 0.9977 - precision: 0.9466 - recall: 0.9073 - val_loss: 0.2263 - val_accuracy: 0.9252 - val_auc: 0.9965 - val_precision: 0.9323 - val_recall: 0.9182
#
# Epoch 00061: val_loss did not improve from 0.21227
# Epoch 62/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.9328 - auc: 0.9984 - precision: 0.9516 - recall: 0.9117 - val_loss: 0.2169 - val_accuracy: 0.9281 - val_auc: 0.9964 - val_precision: 0.9369 - val_recall: 0.9211
#
# Epoch 00062: val_loss did not improve from 0.21227
# Epoch 00062: early stopping
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99        70
#            2       0.97      0.91      0.94       496
#            3       0.67      0.98      0.80        44
#            4       0.97      1.00      0.98        29
#            5       0.97      0.94      0.95       617
#            6       0.55      0.82      0.66        56
#            7       0.82      0.88      0.85        16
#            8       0.89      1.00      0.94        16
#            9       0.67      0.53      0.59        19
#           10       1.00      0.98      0.99       122
#           11       1.00      0.98      0.99       195
#           12       0.50      0.71      0.59        34
#           13       1.00      1.00      1.00        10
#
#     accuracy                           0.93      1724
#    macro avg       0.85      0.90      0.87      1724
# weighted avg       0.94      0.93      0.93      1724
#
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2123 - accuracy: 0.9327 - auc: 0.9968 - precision: 0.9398 - recall: 0.9229

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="labels", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="labels", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9249806651198763: Misclassification: 0.07501933488012369
#               precision    recall  f1-score   support
#
#            1       0.93      0.97      0.95       104
#            2       0.94      0.97      0.96       745
#            3       0.82      0.76      0.79        66
#            4       0.91      0.98      0.94        43
#            5       0.92      0.97      0.94       926
#            6       0.46      0.25      0.32        85
#            7       1.00      0.79      0.88        24
#            8       1.00      0.88      0.93        24
#            9       0.86      0.21      0.34        28
#           10       1.00      0.98      0.99       182
#           11       0.99      0.96      0.97       293
#           12       0.69      0.69      0.69        51
#           13       1.00      1.00      1.00        15
#
#     accuracy                           0.92      2586
#    macro avg       0.89      0.80      0.82      2586
# weighted avg       0.92      0.92      0.92      2586

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="labels", top=2, figsize=(6,10), restricted=False)

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 500 genes across 8617 cells

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  56.31539225578308
